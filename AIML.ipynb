# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, explained_variance_score
from sklearn.preprocessing import StandardScaler

# %%
data = pd.read_csv('purchasedata.csv', header=[0,1,2])

data.columns.name = None

print(data)
# Out:
#        A_Plus                                                              \
#         Cm-01                                               Cm-02
#          DATE ITEM_NO            ITEM_NAME STOCK SALE        DATE ITEM_NO
# 0  01-07-2023   11101     Apple 14 Pro Max     5    1  01-07-2023   11106
# 1  02-07-2023   11102         Vivo 15 Plus    10    8  02-07-2023   11107
# 2  03-07-2023   11103     Apple 13 Pro Max     4    0  03-07-2023   11108
# 3  04-07-2023   11104  Oppo Reno 10 Series     4    1  04-07-2023   11109
# 4  05-07-2023   11105          samsung S23    12    9  05-07-2023   11110
# 5  06-07-2023   15786           Realme C52    14   11  06-07-2023   11789
# 6  07-07-2023   15787       OnePlus Nord 3     8    6  07-07-2023   12346
#
#                                    ...           C          \
#                                    ...       Cm-12
#              ITEM_NAME STOCK SALE  ...        DATE ITEM_NO
# 0     Apple 14 Pro Max     5    0  ...  01-07-2023   11156
# 1        Apple 14 Plus    10    4  ...  02-07-2023   11157
# 2     Apple 13 Pro Max     4    3  ...  03-07-2023   11158
# 3  Oppo Reno 10 Series     4    2  ...  04-07-2023   11159
# 4  Oppo Reno 09 series    12    4  ...  05-07-2023   11160
# 5         Realme 11Pro     6    3  ...  06-07-2023   11178
# 6           Realme C52     8    4  ...  07-07-2023   11179
#
#                                                                             \
#                                         Cm-13
#              ITEM_NAME STOCK SALE        DATE ITEM_NO            ITEM_NAME
# 0                Redmi     5    4  01-07-2023   11161     Apple 14 Pro Max
# 1         Vivo 15 Plus    10    8  02-07-2023   11162        Apple 14 Plus
# 2     Apple 13 Pro Max     4    1  03-07-2023   11163     Apple 13 Pro Max
# 3  Oppo Reno 10 Series     4    2  04-07-2023   11164  Oppo Reno 10 Series
# 4  Oppo Reno 09 series    12    8  05-07-2023   11165  Oppo Reno 09 series
# 5         Realme 11Pro     7    6  06-07-2023   11639           Realme C52
# 6   Samsung Galaxy F54     7    1  07-07-2023   11640       OnePlus Nord 3
#
#
#
#   STOCK SALE
# 0     5    3
# 1    10    9
# 2     4    1
# 3     4    4
# 4    12   11
# 5     8    4
# 6     5    0
#
# [7 rows x 65 columns]

# %%
data
# Out:
#        A_Plus                                                              \
#         Cm-01                                               Cm-02
#          DATE ITEM_NO            ITEM_NAME STOCK SALE        DATE ITEM_NO
# 0  01-07-2023   11101     Apple 14 Pro Max     5    1  01-07-2023   11106
# 1  02-07-2023   11102         Vivo 15 Plus    10    8  02-07-2023   11107
# 2  03-07-2023   11103     Apple 13 Pro Max     4    0  03-07-2023   11108
# 3  04-07-2023   11104  Oppo Reno 10 Series     4    1  04-07-2023   11109
# 4  05-07-2023   11105          samsung S23    12    9  05-07-2023   11110
# 5  06-07-2023   15786           Realme C52    14   11  06-07-2023   11789
# 6  07-07-2023   15787       OnePlus Nord 3     8    6  07-07-2023   12346
#
#                                    ...           C          \
#                                    ...       Cm-12
#              ITEM_NAME STOCK SALE  ...        DATE ITEM_NO
# 0     Apple 14 Pro Max     5    0  ...  01-07-2023   11156
# 1        Apple 14 Plus    10    4  ...  02-07-2023   11157
# 2     Apple 13 Pro Max     4    3  ...  03-07-2023   11158
# 3  Oppo Reno 10 Series     4    2  ...  04-07-2023   11159
# 4  Oppo Reno 09 series    12    4  ...  05-07-2023   11160
# 5         Realme 11Pro     6    3  ...  06-07-2023   11178
# 6           Realme C52     8    4  ...  07-07-2023   11179
#
#                                                                             \
#                                         Cm-13
#              ITEM_NAME STOCK SALE        DATE ITEM_NO            ITEM_NAME
# 0                Redmi     5    4  01-07-2023   11161     Apple 14 Pro Max
# 1         Vivo 15 Plus    10    8  02-07-2023   11162        Apple 14 Plus
# 2     Apple 13 Pro Max     4    1  03-07-2023   11163     Apple 13 Pro Max
# 3  Oppo Reno 10 Series     4    2  04-07-2023   11164  Oppo Reno 10 Series
# 4  Oppo Reno 09 series    12    8  05-07-2023   11165  Oppo Reno 09 series
# 5         Realme 11Pro     7    6  06-07-2023   11639           Realme C52
# 6   Samsung Galaxy F54     7    1  07-07-2023   11640       OnePlus Nord 3
#
#
#
#   STOCK SALE
# 0     5    3
# 1    10    9
# 2     4    1
# 3     4    4
# 4    12   11
# 5     8    4
# 6     5    0
#
# [7 rows x 65 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 65 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   (A_Plus, Cm-01, DATE)       7 non-null      object
#  1   (A_Plus, Cm-01, ITEM_NO)    7 non-null      int64
#  2   (A_Plus, Cm-01, ITEM_NAME)  7 non-null      object
#  3   (A_Plus, Cm-01, STOCK)      7 non-null      int64
#  4   (A_Plus, Cm-01, SALE)       7 non-null      int64
#  5   (A_Plus, Cm-02, DATE)       7 non-null      object
#  6   (A_Plus, Cm-02, ITEM_NO)    7 non-null      int64
#  7   (A_Plus, Cm-02, ITEM_NAME)  7 non-null      object
#  8   (A_Plus, Cm-02, STOCK)      7 non-null      int64
#  9   (A_Plus, Cm-02, SALE)       7 non-null      int64
#  10  (A_Plus, Cm-03, DATE)       7 non-null      object
#  11  (A_Plus, Cm-03, ITEM_NO)    7 non-null      int64
#  12  (A_Plus, Cm-03, ITEM_NAME)  7 non-null      object
#  13  (A_Plus, Cm-03, STOCK)      7 non-null      int64
#  14  (A_Plus, Cm-03, SALE)       7 non-null      int64
#  15  (A, Cm-04, DATE)            7 non-null      object
#  16  (A, Cm-04, ITEM_NO)         7 non-null      int64
#  17  (A, Cm-04, ITEM_NAME)       7 non-null      object
#  18  (A, Cm-04, STOCK)           7 non-null      int64
#  19  (A, Cm-04, SALE)            7 non-null      int64
#  20  (A, Cm-05, DATE)            7 non-null      object
#  21  (A, Cm-05, ITEM_NO)         7 non-null      int64
#  22  (A, Cm-05, ITEM_NAME)       7 non-null      object
#  23  (A, Cm-05, STOCK)           7 non-null      int64
#  24  (A, Cm-05, SALE)            7 non-null      int64
#  25  (B, Cm-06, DATE)            7 non-null      object
#  26  (B, Cm-06, ITEM_NO)         7 non-null      int64
#  27  (B, Cm-06, ITEM_NAME)       7 non-null      object
#  28  (B, Cm-06, STOCK)           7 non-null      int64
#  29  (B, Cm-06, SALE)            7 non-null      int64
#  30  (B, Cm-07, DATE)            7 non-null      object
#  31  (B, Cm-07, ITEM_NO)         7 non-null      int64
#  32  (B, Cm-07, ITEM_NAME)       7 non-null      object
#  33  (B, Cm-07, STOCK)           7 non-null      int64
#  34  (B, Cm-07, SALE)            7 non-null      int64
#  35  (B, Cm-08, DATE)            7 non-null      object
#  36  (B, Cm-08, ITEM_NO)         7 non-null      int64
#  37  (B, Cm-08, ITEM_NAME)       7 non-null      object
#  38  (B, Cm-08, STOCK)           7 non-null      int64
#  39  (B, Cm-08, SALE)            7 non-null      int64
#  40  (C, Cm-09, DATE)            7 non-null      object
#  41  (C, Cm-09, ITEM_NO)         7 non-null      int64
#  42  (C, Cm-09, ITEM_NAME)       7 non-null      object
#  43  (C, Cm-09, STOCK)           7 non-null      int64
#  44  (C, Cm-09, SALE)            7 non-null      int64
#  45  (C, Cm-10, DATE)            7 non-null      object
#  46  (C, Cm-10, ITEM_NO)         7 non-null      int64
#  47  (C, Cm-10, ITEM_NAME)       7 non-null      object
#  48  (C, Cm-10, STOCK)           7 non-null      int64
#  49  (C, Cm-10, SALE)            7 non-null      int64
#  50  (C, Cm-11, DATE)            7 non-null      object
#  51  (C, Cm-11, ITEM_NO)         7 non-null      int64
#  52  (C, Cm-11, ITEM_NAME)       7 non-null      object
#  53  (C, Cm-11, STOCK)           7 non-null      int64
#  54  (C, Cm-11, SALE)            7 non-null      int64
#  55  (C, Cm-12, DATE)            7 non-null      object
#  56  (C, Cm-12, ITEM_NO)         7 non-null      int64
#  57  (C, Cm-12, ITEM_NAME)       7 non-null      object
#  58  (C, Cm-12, STOCK)           7 non-null      int64
#  59  (C, Cm-12, SALE)            7 non-null      int64
#  60  (C, Cm-13, DATE)            7 non-null      object
#  61  (C, Cm-13, ITEM_NO)         7 non-null      int64
#  62  (C, Cm-13, ITEM_NAME)       7 non-null      object
#  63  (C, Cm-13, STOCK)           7 non-null      int64
#  64  (C, Cm-13, SALE)            7 non-null      int64
# dtypes: int64(39), object(26)
# memory usage: 3.7+ KB

# %%
data.columns.levels
# Out:
# FrozenList([['A', 'A_Plus', 'B', 'C'], ['Cm-01', 'Cm-02', 'Cm-03', 'Cm-04', 'Cm-05', 'Cm-06', 'Cm-07', 'Cm-08', 'Cm-09', 'Cm-10', 'Cm-11', 'Cm-12', 'Cm-13'], ['DATE', 'ITEM_NAME', 'ITEM_NO', 'SALE', 'STOCK']])

# %%
data
# Out:
#        A_Plus                                                              \
#         Cm-01                                               Cm-02
#          DATE ITEM_NO            ITEM_NAME STOCK SALE        DATE ITEM_NO
# 0  01-07-2023   11101     Apple 14 Pro Max     5    1  01-07-2023   11106
# 1  02-07-2023   11102         Vivo 15 Plus    10    8  02-07-2023   11107
# 2  03-07-2023   11103     Apple 13 Pro Max     4    0  03-07-2023   11108
# 3  04-07-2023   11104  Oppo Reno 10 Series     4    1  04-07-2023   11109
# 4  05-07-2023   11105          samsung S23    12    9  05-07-2023   11110
# 5  06-07-2023   15786           Realme C52    14   11  06-07-2023   11789
# 6  07-07-2023   15787       OnePlus Nord 3     8    6  07-07-2023   12346
#
#                                    ...           C          \
#                                    ...       Cm-12
#              ITEM_NAME STOCK SALE  ...        DATE ITEM_NO
# 0     Apple 14 Pro Max     5    0  ...  01-07-2023   11156
# 1        Apple 14 Plus    10    4  ...  02-07-2023   11157
# 2     Apple 13 Pro Max     4    3  ...  03-07-2023   11158
# 3  Oppo Reno 10 Series     4    2  ...  04-07-2023   11159
# 4  Oppo Reno 09 series    12    4  ...  05-07-2023   11160
# 5         Realme 11Pro     6    3  ...  06-07-2023   11178
# 6           Realme C52     8    4  ...  07-07-2023   11179
#
#                                                                             \
#                                         Cm-13
#              ITEM_NAME STOCK SALE        DATE ITEM_NO            ITEM_NAME
# 0                Redmi     5    4  01-07-2023   11161     Apple 14 Pro Max
# 1         Vivo 15 Plus    10    8  02-07-2023   11162        Apple 14 Plus
# 2     Apple 13 Pro Max     4    1  03-07-2023   11163     Apple 13 Pro Max
# 3  Oppo Reno 10 Series     4    2  04-07-2023   11164  Oppo Reno 10 Series
# 4  Oppo Reno 09 series    12    8  05-07-2023   11165  Oppo Reno 09 series
# 5         Realme 11Pro     7    6  06-07-2023   11639           Realme C52
# 6   Samsung Galaxy F54     7    1  07-07-2023   11640       OnePlus Nord 3
#
#
#
#   STOCK SALE
# 0     5    3
# 1    10    9
# 2     4    1
# 3     4    4
# 4    12   11
# 5     8    4
# 6     5    0
#
# [7 rows x 65 columns]

# %%
# Individual store data

data['A_Plus','Cm-01']
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_17260\3907639560.py:3: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['A_Plus','Cm-01']
#          DATE  ITEM_NO            ITEM_NAME  STOCK  SALE
# 0  01-07-2023    11101     Apple 14 Pro Max      5     1
# 1  02-07-2023    11102         Vivo 15 Plus     10     8
# 2  03-07-2023    11103     Apple 13 Pro Max      4     0
# 3  04-07-2023    11104  Oppo Reno 10 Series      4     1
# 4  05-07-2023    11105          samsung S23     12     9
# 5  06-07-2023    15786           Realme C52     14    11
# 6  07-07-2023    15787       OnePlus Nord 3      8     6

# %%
print(data.columns)
# Out:
# MultiIndex([('A_Plus', 'Cm-01',      'DATE'),
#             ('A_Plus', 'Cm-01',   'ITEM_NO'),
#             ('A_Plus', 'Cm-01', 'ITEM_NAME'),
#             ('A_Plus', 'Cm-01',     'STOCK'),
#             ('A_Plus', 'Cm-01',      'SALE'),
#             ('A_Plus', 'Cm-02',      'DATE'),
#             ('A_Plus', 'Cm-02',   'ITEM_NO'),
#             ('A_Plus', 'Cm-02', 'ITEM_NAME'),
#             ('A_Plus', 'Cm-02',     'STOCK'),
#             ('A_Plus', 'Cm-02',      'SALE'),
#             ('A_Plus', 'Cm-03',      'DATE'),
#             ('A_Plus', 'Cm-03',   'ITEM_NO'),
#             ('A_Plus', 'Cm-03', 'ITEM_NAME'),
#             ('A_Plus', 'Cm-03',     'STOCK'),
#             ('A_Plus', 'Cm-03',      'SALE'),
#             (     'A', 'Cm-04',      'DATE'),
#             (     'A', 'Cm-04',   'ITEM_NO'),
#             (     'A', 'Cm-04', 'ITEM_NAME'),
#             (     'A', 'Cm-04',     'STOCK'),
#             (     'A', 'Cm-04',      'SALE'),
#             (     'A', 'Cm-05',      'DATE'),
#             (     'A', 'Cm-05',   'ITEM_NO'),
#             (     'A', 'Cm-05', 'ITEM_NAME'),
#             (     'A', 'Cm-05',     'STOCK'),
#             (     'A', 'Cm-05',      'SALE'),
#             (     'B', 'Cm-06',      'DATE'),
#             (     'B', 'Cm-06',   'ITEM_NO'),
#             (     'B', 'Cm-06', 'ITEM_NAME'),
#             (     'B', 'Cm-06',     'STOCK'),
#             (     'B', 'Cm-06',      'SALE'),
#             (     'B', 'Cm-07',      'DATE'),
#             (     'B', 'Cm-07',   'ITEM_NO'),
#             (     'B', 'Cm-07', 'ITEM_NAME'),
#             (     'B', 'Cm-07',     'STOCK'),
#             (     'B', 'Cm-07',      'SALE'),
#             (     'B', 'Cm-08',      'DATE'),
#             (     'B', 'Cm-08',   'ITEM_NO'),
#             (     'B', 'Cm-08', 'ITEM_NAME'),
#             (     'B', 'Cm-08',     'STOCK'),
#             (     'B', 'Cm-08',      'SALE'),
#             (     'C', 'Cm-09',      'DATE'),
#             (     'C', 'Cm-09',   'ITEM_NO'),
#             (     'C', 'Cm-09', 'ITEM_NAME'),
#             (     'C', 'Cm-09',     'STOCK'),
#             (     'C', 'Cm-09',      'SALE'),
#             (     'C', 'Cm-10',      'DATE'),
#             (     'C', 'Cm-10',   'ITEM_NO'),
#             (     'C', 'Cm-10', 'ITEM_NAME'),
#             (     'C', 'Cm-10',     'STOCK'),
#             (     'C', 'Cm-10',      'SALE'),
#             (     'C', 'Cm-11',      'DATE'),
#             (     'C', 'Cm-11',   'ITEM_NO'),
#             (     'C', 'Cm-11', 'ITEM_NAME'),
#             (     'C', 'Cm-11',     'STOCK'),
#             (     'C', 'Cm-11',      'SALE'),
#             (     'C', 'Cm-12',      'DATE'),
#             (     'C', 'Cm-12',   'ITEM_NO'),
#             (     'C', 'Cm-12', 'ITEM_NAME'),
#             (     'C', 'Cm-12',     'STOCK'),
#             (     'C', 'Cm-12',      'SALE'),
#             (     'C', 'Cm-13',      'DATE'),
#             (     'C', 'Cm-13',   'ITEM_NO'),
#             (     'C', 'Cm-13', 'ITEM_NAME'),
#             (     'C', 'Cm-13',     'STOCK'),
#             (     'C', 'Cm-13',      'SALE')],
#            )

# %% [markdown]
# ### Calculate Sales Percentage for each Store

# %%
for store in data.columns.get_level_values(0).unique():
    for cm in data.columns.get_level_values(1).unique():
        try:
            sale_data = data.loc[:, (store, cm, 'SALE')]
            stock_data = data.loc[:, (store, cm, 'STOCK')]
            data[(store, cm, 'Sale_Percentage')] = (sale_data / stock_data) * 100
        except KeyError:
            pass

print(data)
# Out:
#        A_Plus                                                              \
#         Cm-01                                               Cm-02
#          DATE ITEM_NO            ITEM_NAME STOCK SALE        DATE ITEM_NO
# 0  01-07-2023   11101     Apple 14 Pro Max     5    1  01-07-2023   11106
# 1  02-07-2023   11102         Vivo 15 Plus    10    8  02-07-2023   11107
# 2  03-07-2023   11103     Apple 13 Pro Max     4    0  03-07-2023   11108
# 3  04-07-2023   11104  Oppo Reno 10 Series     4    1  04-07-2023   11109
# 4  05-07-2023   11105          samsung S23    12    9  05-07-2023   11110
# 5  06-07-2023   15786           Realme C52    14   11  06-07-2023   11789
# 6  07-07-2023   15787       OnePlus Nord 3     8    6  07-07-2023   12346
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 0     Apple 14 Pro Max     5    0  ...       60.000000       40.000000
# 1        Apple 14 Plus    10    4  ...       60.000000       90.000000
# 2     Apple 13 Pro Max     4    3  ...       50.000000       25.000000
# 3  Oppo Reno 10 Series     4    2  ...       50.000000       75.000000
# 4  Oppo Reno 09 series    12    4  ...      100.000000       33.333333
# 5         Realme 11Pro     6    3  ...       13.333333       12.500000
# 6           Realme C52     8    4  ...       42.857143       77.777778
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0            20.0       40.000000        0.000000       40.000000
# 1            40.0       40.000000       40.000000       30.000000
# 2            50.0       75.000000       25.000000       50.000000
# 3           100.0       50.000000       50.000000       50.000000
# 4            75.0       41.666667       33.333333       33.333333
# 5           100.0        0.000000       90.909091       60.000000
# 6             0.0       13.333333      100.000000       62.500000
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0       20.000000            40.0       80.000000       60.000000
# 1       20.000000            50.0       80.000000       90.000000
# 2       75.000000            75.0       25.000000       25.000000
# 3       50.000000            50.0       50.000000      100.000000
# 4       41.666667            25.0       66.666667       91.666667
# 5       50.000000            25.0       85.714286       50.000000
# 6       66.666667            90.0       14.285714        0.000000
#
# [7 rows x 78 columns]

# %%
data
# Out:
#        A_Plus                                                              \
#         Cm-01                                               Cm-02
#          DATE ITEM_NO            ITEM_NAME STOCK SALE        DATE ITEM_NO
# 0  01-07-2023   11101     Apple 14 Pro Max     5    1  01-07-2023   11106
# 1  02-07-2023   11102         Vivo 15 Plus    10    8  02-07-2023   11107
# 2  03-07-2023   11103     Apple 13 Pro Max     4    0  03-07-2023   11108
# 3  04-07-2023   11104  Oppo Reno 10 Series     4    1  04-07-2023   11109
# 4  05-07-2023   11105          samsung S23    12    9  05-07-2023   11110
# 5  06-07-2023   15786           Realme C52    14   11  06-07-2023   11789
# 6  07-07-2023   15787       OnePlus Nord 3     8    6  07-07-2023   12346
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 0     Apple 14 Pro Max     5    0  ...       60.000000       40.000000
# 1        Apple 14 Plus    10    4  ...       60.000000       90.000000
# 2     Apple 13 Pro Max     4    3  ...       50.000000       25.000000
# 3  Oppo Reno 10 Series     4    2  ...       50.000000       75.000000
# 4  Oppo Reno 09 series    12    4  ...      100.000000       33.333333
# 5         Realme 11Pro     6    3  ...       13.333333       12.500000
# 6           Realme C52     8    4  ...       42.857143       77.777778
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0            20.0       40.000000        0.000000       40.000000
# 1            40.0       40.000000       40.000000       30.000000
# 2            50.0       75.000000       25.000000       50.000000
# 3           100.0       50.000000       50.000000       50.000000
# 4            75.0       41.666667       33.333333       33.333333
# 5           100.0        0.000000       90.909091       60.000000
# 6             0.0       13.333333      100.000000       62.500000
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0       20.000000            40.0       80.000000       60.000000
# 1       20.000000            50.0       80.000000       90.000000
# 2       75.000000            75.0       25.000000       25.000000
# 3       50.000000            50.0       50.000000      100.000000
# 4       41.666667            25.0       66.666667       91.666667
# 5       50.000000            25.0       85.714286       50.000000
# 6       66.666667            90.0       14.285714        0.000000
#
# [7 rows x 78 columns]

# %%
# Sale_Percentage for single store

data['A_Plus','Cm-01']
# Out:
# C:\Users\deepa\AppData\Local\Temp\ipykernel_17260\1453481835.py:3: PerformanceWarning: indexing past lexsort depth may impact performance.
#   data['A_Plus','Cm-01']
#          DATE  ITEM_NO            ITEM_NAME  STOCK  SALE  Sale_Percentage
# 0  01-07-2023    11101     Apple 14 Pro Max      5     1        20.000000
# 1  02-07-2023    11102         Vivo 15 Plus     10     8        80.000000
# 2  03-07-2023    11103     Apple 13 Pro Max      4     0         0.000000
# 3  04-07-2023    11104  Oppo Reno 10 Series      4     1        25.000000
# 4  05-07-2023    11105          samsung S23     12     9        75.000000
# 5  06-07-2023    15786           Realme C52     14    11        78.571429
# 6  07-07-2023    15787       OnePlus Nord 3      8     6        75.000000

# %%
selected_columns = [65,66,67,68,69,70,71,72,73,74,75,76,77]
df1 = data.iloc[:, selected_columns]
print(df1)
# Out:
#            A_Plus                                               A  \
#             Cm-01           Cm-02           Cm-03           Cm-04
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0       20.000000        0.000000       40.000000       60.000000
# 1       80.000000       40.000000       70.000000       60.000000
# 2        0.000000       75.000000       25.000000       50.000000
# 3       25.000000       50.000000       75.000000       50.000000
# 4       75.000000       33.333333       66.666667      100.000000
# 5       78.571429       50.000000       87.500000       13.333333
# 6       75.000000       50.000000       44.444444       42.857143
#
#                                 B                                  \
#             Cm-05           Cm-06           Cm-07           Cm-08
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0       40.000000            20.0       40.000000        0.000000
# 1       90.000000            40.0       40.000000       40.000000
# 2       25.000000            50.0       75.000000       25.000000
# 3       75.000000           100.0       50.000000       50.000000
# 4       33.333333            75.0       41.666667       33.333333
# 5       12.500000           100.0        0.000000       90.909091
# 6       77.777778             0.0       13.333333      100.000000
#
#                 C                                                  \
#             Cm-09           Cm-10           Cm-11           Cm-12
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0       40.000000       20.000000            40.0       80.000000
# 1       30.000000       20.000000            50.0       80.000000
# 2       50.000000       75.000000            75.0       25.000000
# 3       50.000000       50.000000            50.0       50.000000
# 4       33.333333       41.666667            25.0       66.666667
# 5       60.000000       50.000000            25.0       85.714286
# 6       62.500000       66.666667            90.0       14.285714
#
#
#             Cm-13
#   Sale_Percentage
# 0       60.000000
# 1       90.000000
# 2       25.000000
# 3      100.000000
# 4       91.666667
# 5       50.000000
# 6        0.000000

# %%
sale = data[("A_Plus", "Cm-01", "Sale_Percentage")] > 50
sale
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# Name: (A_Plus, Cm-01, Sale_Percentage), dtype: bool

# %%
data
# Out:
#        A_Plus                                                              \
#         Cm-01                                               Cm-02
#          DATE ITEM_NO            ITEM_NAME STOCK SALE        DATE ITEM_NO
# 0  01-07-2023   11101     Apple 14 Pro Max     5    1  01-07-2023   11106
# 1  02-07-2023   11102         Vivo 15 Plus    10    8  02-07-2023   11107
# 2  03-07-2023   11103     Apple 13 Pro Max     4    0  03-07-2023   11108
# 3  04-07-2023   11104  Oppo Reno 10 Series     4    1  04-07-2023   11109
# 4  05-07-2023   11105          samsung S23    12    9  05-07-2023   11110
# 5  06-07-2023   15786           Realme C52    14   11  06-07-2023   11789
# 6  07-07-2023   15787       OnePlus Nord 3     8    6  07-07-2023   12346
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 0     Apple 14 Pro Max     5    0  ...       60.000000       40.000000
# 1        Apple 14 Plus    10    4  ...       60.000000       90.000000
# 2     Apple 13 Pro Max     4    3  ...       50.000000       25.000000
# 3  Oppo Reno 10 Series     4    2  ...       50.000000       75.000000
# 4  Oppo Reno 09 series    12    4  ...      100.000000       33.333333
# 5         Realme 11Pro     6    3  ...       13.333333       12.500000
# 6           Realme C52     8    4  ...       42.857143       77.777778
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0            20.0       40.000000        0.000000       40.000000
# 1            40.0       40.000000       40.000000       30.000000
# 2            50.0       75.000000       25.000000       50.000000
# 3           100.0       50.000000       50.000000       50.000000
# 4            75.0       41.666667       33.333333       33.333333
# 5           100.0        0.000000       90.909091       60.000000
# 6             0.0       13.333333      100.000000       62.500000
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0       20.000000            40.0       80.000000       60.000000
# 1       20.000000            50.0       80.000000       90.000000
# 2       75.000000            75.0       25.000000       25.000000
# 3       50.000000            50.0       50.000000      100.000000
# 4       41.666667            25.0       66.666667       91.666667
# 5       50.000000            25.0       85.714286       50.000000
# 6       66.666667            90.0       14.285714        0.000000
#
# [7 rows x 78 columns]

# %%
# Filter Sale_Percentage > 80% for each group ('A_Plus', 'A', 'B', 'C')

a_plus = data[('A_Plus', 'Cm-01', 'Sale_Percentage')] > 80.0
a = data[('A', 'Cm-04', 'Sale_Percentage')] > 80.0
b = data[('B', 'Cm-06', 'Sale_Percentage')] > 80.0
c = data[('C', 'Cm-09', 'Sale_Percentage')] > 80.0


a_plus_data = data[a_plus]
a_data = data[a]
b_data = data[b]
c_data = data[c]

# Print the filtered results
if not a_plus_data.empty:
    print("A_Plus:")
    print(a_plus_data)

if not a_data.empty:
    print("\nA:")
    print(a_data)

if not b_data.empty:
    print("\nB:")
    print(b_data)

if not c_data.empty:
    print("\nC:")
    print(c_data)
# Out:
# A:
#        A_Plus                                                      \
#         Cm-01                                       Cm-02
#          DATE ITEM_NO    ITEM_NAME STOCK SALE        DATE ITEM_NO
# 4  05-07-2023   11105  samsung S23    12    9  05-07-2023   11110
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 4  Oppo Reno 09 series    12    4  ...           100.0       33.333333
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 4            75.0       41.666667       33.333333       33.333333
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 4       41.666667            25.0       66.666667       91.666667
#
# [1 rows x 78 columns]
#
# B:
#        A_Plus                                                              \
#         Cm-01                                               Cm-02
#          DATE ITEM_NO            ITEM_NAME STOCK SALE        DATE ITEM_NO
# 3  04-07-2023   11104  Oppo Reno 10 Series     4    1  04-07-2023   11109
# 5  06-07-2023   15786           Realme C52    14   11  06-07-2023   11789
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 3  Oppo Reno 10 Series     4    2  ...       50.000000            75.0
# 5         Realme 11Pro     6    3  ...       13.333333            12.5
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 3           100.0            50.0       50.000000            50.0
# 5           100.0             0.0       90.909091            60.0
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 3            50.0            50.0       50.000000           100.0
# 5            50.0            25.0       85.714286            50.0
#
# [2 rows x 78 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 78 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   (A_Plus, Cm-01, DATE)             7 non-null      object
#  1   (A_Plus, Cm-01, ITEM_NO)          7 non-null      int64
#  2   (A_Plus, Cm-01, ITEM_NAME)        7 non-null      object
#  3   (A_Plus, Cm-01, STOCK)            7 non-null      int64
#  4   (A_Plus, Cm-01, SALE)             7 non-null      int64
#  5   (A_Plus, Cm-02, DATE)             7 non-null      object
#  6   (A_Plus, Cm-02, ITEM_NO)          7 non-null      int64
#  7   (A_Plus, Cm-02, ITEM_NAME)        7 non-null      object
#  8   (A_Plus, Cm-02, STOCK)            7 non-null      int64
#  9   (A_Plus, Cm-02, SALE)             7 non-null      int64
#  10  (A_Plus, Cm-03, DATE)             7 non-null      object
#  11  (A_Plus, Cm-03, ITEM_NO)          7 non-null      int64
#  12  (A_Plus, Cm-03, ITEM_NAME)        7 non-null      object
#  13  (A_Plus, Cm-03, STOCK)            7 non-null      int64
#  14  (A_Plus, Cm-03, SALE)             7 non-null      int64
#  15  (A, Cm-04, DATE)                  7 non-null      object
#  16  (A, Cm-04, ITEM_NO)               7 non-null      int64
#  17  (A, Cm-04, ITEM_NAME)             7 non-null      object
#  18  (A, Cm-04, STOCK)                 7 non-null      int64
#  19  (A, Cm-04, SALE)                  7 non-null      int64
#  20  (A, Cm-05, DATE)                  7 non-null      object
#  21  (A, Cm-05, ITEM_NO)               7 non-null      int64
#  22  (A, Cm-05, ITEM_NAME)             7 non-null      object
#  23  (A, Cm-05, STOCK)                 7 non-null      int64
#  24  (A, Cm-05, SALE)                  7 non-null      int64
#  25  (B, Cm-06, DATE)                  7 non-null      object
#  26  (B, Cm-06, ITEM_NO)               7 non-null      int64
#  27  (B, Cm-06, ITEM_NAME)             7 non-null      object
#  28  (B, Cm-06, STOCK)                 7 non-null      int64
#  29  (B, Cm-06, SALE)                  7 non-null      int64
#  30  (B, Cm-07, DATE)                  7 non-null      object
#  31  (B, Cm-07, ITEM_NO)               7 non-null      int64
#  32  (B, Cm-07, ITEM_NAME)             7 non-null      object
#  33  (B, Cm-07, STOCK)                 7 non-null      int64
#  34  (B, Cm-07, SALE)                  7 non-null      int64
#  35  (B, Cm-08, DATE)                  7 non-null      object
#  36  (B, Cm-08, ITEM_NO)               7 non-null      int64
#  37  (B, Cm-08, ITEM_NAME)             7 non-null      object
#  38  (B, Cm-08, STOCK)                 7 non-null      int64
#  39  (B, Cm-08, SALE)                  7 non-null      int64
#  40  (C, Cm-09, DATE)                  7 non-null      object
#  41  (C, Cm-09, ITEM_NO)               7 non-null      int64
#  42  (C, Cm-09, ITEM_NAME)             7 non-null      object
#  43  (C, Cm-09, STOCK)                 7 non-null      int64
#  44  (C, Cm-09, SALE)                  7 non-null      int64
#  45  (C, Cm-10, DATE)                  7 non-null      object
#  46  (C, Cm-10, ITEM_NO)               7 non-null      int64
#  47  (C, Cm-10, ITEM_NAME)             7 non-null      object
#  48  (C, Cm-10, STOCK)                 7 non-null      int64
#  49  (C, Cm-10, SALE)                  7 non-null      int64
#  50  (C, Cm-11, DATE)                  7 non-null      object
#  51  (C, Cm-11, ITEM_NO)               7 non-null      int64
#  52  (C, Cm-11, ITEM_NAME)             7 non-null      object
#  53  (C, Cm-11, STOCK)                 7 non-null      int64
#  54  (C, Cm-11, SALE)                  7 non-null      int64
#  55  (C, Cm-12, DATE)                  7 non-null      object
#  56  (C, Cm-12, ITEM_NO)               7 non-null      int64
#  57  (C, Cm-12, ITEM_NAME)             7 non-null      object
#  58  (C, Cm-12, STOCK)                 7 non-null      int64
#  59  (C, Cm-12, SALE)                  7 non-null      int64
#  60  (C, Cm-13, DATE)                  7 non-null      object
#  61  (C, Cm-13, ITEM_NO)               7 non-null      int64
#  62  (C, Cm-13, ITEM_NAME)             7 non-null      object
#  63  (C, Cm-13, STOCK)                 7 non-null      int64
#  64  (C, Cm-13, SALE)                  7 non-null      int64
#  65  (A_Plus, Cm-01, Sale_Percentage)  7 non-null      float64
#  66  (A_Plus, Cm-02, Sale_Percentage)  7 non-null      float64
#  67  (A_Plus, Cm-03, Sale_Percentage)  7 non-null      float64
#  68  (A, Cm-04, Sale_Percentage)       7 non-null      float64
#  69  (A, Cm-05, Sale_Percentage)       7 non-null      float64
#  70  (B, Cm-06, Sale_Percentage)       7 non-null      float64
#  71  (B, Cm-07, Sale_Percentage)       7 non-null      float64
#  72  (B, Cm-08, Sale_Percentage)       7 non-null      float64
#  73  (C, Cm-09, Sale_Percentage)       7 non-null      float64
#  74  (C, Cm-10, Sale_Percentage)       7 non-null      float64
#  75  (C, Cm-11, Sale_Percentage)       7 non-null      float64
#  76  (C, Cm-12, Sale_Percentage)       7 non-null      float64
#  77  (C, Cm-13, Sale_Percentage)       7 non-null      float64
# dtypes: float64(13), int64(39), object(26)
# memory usage: 4.4+ KB

# %%
data.columns.levels
# Out:
# FrozenList([['A', 'A_Plus', 'B', 'C'], ['Cm-01', 'Cm-02', 'Cm-03', 'Cm-04', 'Cm-05', 'Cm-06', 'Cm-07', 'Cm-08', 'Cm-09', 'Cm-10', 'Cm-11', 'Cm-12', 'Cm-13'], ['DATE', 'ITEM_NAME', 'ITEM_NO', 'SALE', 'STOCK', 'Sale_Percentage']])

# %% [markdown]
# ## Drop Date column

# %%
for column in data.columns:
    if 'DATE' in column:
        data.drop(column, axis=1, inplace=True)

# %%
data
# Out:
#    A_Plus                                                                     \
#     Cm-01                                   Cm-02
#   ITEM_NO            ITEM_NAME STOCK SALE ITEM_NO            ITEM_NAME STOCK
# 0   11101     Apple 14 Pro Max     5    1   11106     Apple 14 Pro Max     5
# 1   11102         Vivo 15 Plus    10    8   11107        Apple 14 Plus    10
# 2   11103     Apple 13 Pro Max     4    0   11108     Apple 13 Pro Max     4
# 3   11104  Oppo Reno 10 Series     4    1   11109  Oppo Reno 10 Series     4
# 4   11105          samsung S23    12    9   11110  Oppo Reno 09 series    12
# 5   15786           Realme C52    14   11   11789         Realme 11Pro     6
# 6   15787       OnePlus Nord 3     8    6   12346           Realme C52     8
#
#                                      ...               A                  \
#          Cm-03                       ...           Cm-04           Cm-05
#   SALE ITEM_NO            ITEM_NAME  ... Sale_Percentage Sale_Percentage
# 0    0   11111     Apple 14 Pro Max  ...       60.000000       40.000000
# 1    4   11112        Apple 14 Plus  ...       60.000000       90.000000
# 2    3   11113     Apple 13 Pro Max  ...       50.000000       25.000000
# 3    2   11114          samsung s21  ...       50.000000       75.000000
# 4    4   11115  Oppo Reno 09 series  ...      100.000000       33.333333
# 5    3   16934       OnePlus Nord 3  ...       13.333333       12.500000
# 6    4   16935         Realme 11Pro  ...       42.857143       77.777778
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0            20.0       40.000000        0.000000       40.000000
# 1            40.0       40.000000       40.000000       30.000000
# 2            50.0       75.000000       25.000000       50.000000
# 3           100.0       50.000000       50.000000       50.000000
# 4            75.0       41.666667       33.333333       33.333333
# 5           100.0        0.000000       90.909091       60.000000
# 6             0.0       13.333333      100.000000       62.500000
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0       20.000000            40.0       80.000000       60.000000
# 1       20.000000            50.0       80.000000       90.000000
# 2       75.000000            75.0       25.000000       25.000000
# 3       50.000000            50.0       50.000000      100.000000
# 4       41.666667            25.0       66.666667       91.666667
# 5       50.000000            25.0       85.714286       50.000000
# 6       66.666667            90.0       14.285714        0.000000
#
# [7 rows x 65 columns]

# %%
# Indexing

data.iloc[:, :4]
# Out:
#    A_Plus
#     Cm-01
#   ITEM_NO            ITEM_NAME STOCK SALE
# 0   11101     Apple 14 Pro Max     5    1
# 1   11102         Vivo 15 Plus    10    8
# 2   11103     Apple 13 Pro Max     4    0
# 3   11104  Oppo Reno 10 Series     4    1
# 4   11105          samsung S23    12    9
# 5   15786           Realme C52    14   11
# 6   15787       OnePlus Nord 3     8    6

# %% [markdown]
# ### Label Encoding

# %%
data = data.astype(str)

# %%
label_encoder = LabelEncoder()

# Iterate through each column and encode its values
for column in data.columns:
    data[column] = label_encoder.fit_transform(data[column])

# Convert the columns back to numeric dtype 
data = data.astype(float)

# %%
data
# Out:
#    A_Plus                                                                      \
#     Cm-01                        Cm-02                        Cm-03
#   ITEM_NO ITEM_NAME STOCK SALE ITEM_NO ITEM_NAME STOCK SALE ITEM_NO ITEM_NAME
# 0     0.0       1.0   4.0  1.0     0.0       2.0   3.0  0.0     0.0       2.0
# 1     1.0       5.0   0.0  4.0     1.0       1.0   0.0  3.0     1.0       1.0
# 2     2.0       0.0   3.0  0.0     2.0       0.0   2.0  2.0     2.0       0.0
# 3     3.0       3.0   3.0  1.0     3.0       4.0   2.0  1.0     3.0       6.0
# 4     4.0       6.0   1.0  5.0     4.0       3.0   1.0  3.0     4.0       4.0
# 5     5.0       4.0   2.0  2.0     5.0       5.0   4.0  2.0     5.0       3.0
# 6     6.0       2.0   5.0  3.0     6.0       6.0   5.0  3.0     6.0       5.0
#
#    ...               A                               B                  \
#    ...           Cm-04           Cm-05           Cm-06           Cm-07
#    ... Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0  ...             4.0             3.0             2.0             2.0
# 1  ...             4.0             6.0             3.0             2.0
# 2  ...             3.0             1.0             4.0             5.0
# 3  ...             3.0             4.0             1.0             4.0
# 4  ...             0.0             2.0             5.0             3.0
# 5  ...             1.0             0.0             1.0             0.0
# 6  ...             2.0             5.0             0.0             1.0
#
#                                 C                                  \
#             Cm-08           Cm-09           Cm-10           Cm-11
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             0.0             2.0             0.0             1.0
# 1             4.0             0.0             0.0             2.0
# 2             2.0             3.0             4.0             3.0
# 3             5.0             3.0             2.0             2.0
# 4             3.0             1.0             1.0             0.0
# 5             6.0             4.0             2.0             0.0
# 6             1.0             5.0             3.0             4.0
#
#
#             Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage
# 0             4.0             4.0
# 1             4.0             5.0
# 2             1.0             2.0
# 3             2.0             1.0
# 4             3.0             6.0
# 5             5.0             3.0
# 6             0.0             0.0
#
# [7 rows x 65 columns]

# %% [markdown]
# ## Splitting the dataset

# %%
X = data.iloc[:, :-13]

# %%
X
# Out:
#    A_Plus                                                                      \
#     Cm-01                        Cm-02                        Cm-03
#   ITEM_NO ITEM_NAME STOCK SALE ITEM_NO ITEM_NAME STOCK SALE ITEM_NO ITEM_NAME
# 0     0.0       1.0   4.0  1.0     0.0       2.0   3.0  0.0     0.0       2.0
# 1     1.0       5.0   0.0  4.0     1.0       1.0   0.0  3.0     1.0       1.0
# 2     2.0       0.0   3.0  0.0     2.0       0.0   2.0  2.0     2.0       0.0
# 3     3.0       3.0   3.0  1.0     3.0       4.0   2.0  1.0     3.0       6.0
# 4     4.0       6.0   1.0  5.0     4.0       3.0   1.0  3.0     4.0       4.0
# 5     5.0       4.0   2.0  2.0     5.0       5.0   4.0  2.0     5.0       3.0
# 6     6.0       2.0   5.0  3.0     6.0       6.0   5.0  3.0     6.0       5.0
#
#    ...     C
#    ... Cm-11        Cm-12                        Cm-13
#    ... STOCK SALE ITEM_NO ITEM_NAME STOCK SALE ITEM_NO ITEM_NAME STOCK SALE
# 0  ...   4.0  1.0     0.0       4.0   3.0  2.0     0.0       2.0   3.0  3.0
# 1  ...   0.0  3.0     1.0       6.0   0.0  4.0     1.0       1.0   0.0  5.0
# 2  ...   3.0  2.0     2.0       0.0   2.0  0.0     2.0       0.0   2.0  1.0
# 3  ...   3.0  1.0     3.0       2.0   2.0  1.0     3.0       5.0   2.0  4.0
# 4  ...   1.0  2.0     4.0       1.0   1.0  4.0     4.0       4.0   1.0  2.0
# 5  ...   2.0  3.0     5.0       3.0   4.0  3.0     5.0       6.0   4.0  4.0
# 6  ...   2.0  0.0     6.0       5.0   4.0  0.0     6.0       3.0   3.0  0.0
#
# [7 rows x 52 columns]

# %%
y = data.iloc[:, 52:65]

# %%
y
# Out:
#            A_Plus                                               A  \
#             Cm-01           Cm-02           Cm-03           Cm-04
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             1.0             0.0             1.0             4.0
# 1             5.0             2.0             4.0             4.0
# 2             0.0             4.0             0.0             3.0
# 3             2.0             3.0             5.0             3.0
# 4             3.0             1.0             3.0             0.0
# 5             4.0             3.0             6.0             1.0
# 6             3.0             3.0             2.0             2.0
#
#                                 B                                  \
#             Cm-05           Cm-06           Cm-07           Cm-08
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             3.0             2.0             2.0             0.0
# 1             6.0             3.0             2.0             4.0
# 2             1.0             4.0             5.0             2.0
# 3             4.0             1.0             4.0             5.0
# 4             2.0             5.0             3.0             3.0
# 5             0.0             1.0             0.0             6.0
# 6             5.0             0.0             1.0             1.0
#
#                 C                                                  \
#             Cm-09           Cm-10           Cm-11           Cm-12
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             2.0             0.0             1.0             4.0
# 1             0.0             0.0             2.0             4.0
# 2             3.0             4.0             3.0             1.0
# 3             3.0             2.0             2.0             2.0
# 4             1.0             1.0             0.0             3.0
# 5             4.0             2.0             0.0             5.0
# 6             5.0             3.0             4.0             0.0
#
#
#             Cm-13
#   Sale_Percentage
# 0             4.0
# 1             5.0
# 2             2.0
# 3             1.0
# 4             6.0
# 5             3.0
# 6             0.0

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
print("Train data shape:", X_train.shape)
print("Test data shape:", X_test.shape)
print("Train target shape:", y_train.shape)
print("Test target shape:", y_test.shape)
# Out:
# Train data shape: (4, 52)
# Test data shape: (3, 52)
# Train target shape: (4, 13)
# Test target shape: (3, 13)

# %%
print(data.columns)
# Out:
# MultiIndex([('A_Plus', 'Cm-01',         'ITEM_NO'),
#             ('A_Plus', 'Cm-01',       'ITEM_NAME'),
#             ('A_Plus', 'Cm-01',           'STOCK'),
#             ('A_Plus', 'Cm-01',            'SALE'),
#             ('A_Plus', 'Cm-02',         'ITEM_NO'),
#             ('A_Plus', 'Cm-02',       'ITEM_NAME'),
#             ('A_Plus', 'Cm-02',           'STOCK'),
#             ('A_Plus', 'Cm-02',            'SALE'),
#             ('A_Plus', 'Cm-03',         'ITEM_NO'),
#             ('A_Plus', 'Cm-03',       'ITEM_NAME'),
#             ('A_Plus', 'Cm-03',           'STOCK'),
#             ('A_Plus', 'Cm-03',            'SALE'),
#             (     'A', 'Cm-04',         'ITEM_NO'),
#             (     'A', 'Cm-04',       'ITEM_NAME'),
#             (     'A', 'Cm-04',           'STOCK'),
#             (     'A', 'Cm-04',            'SALE'),
#             (     'A', 'Cm-05',         'ITEM_NO'),
#             (     'A', 'Cm-05',       'ITEM_NAME'),
#             (     'A', 'Cm-05',           'STOCK'),
#             (     'A', 'Cm-05',            'SALE'),
#             (     'B', 'Cm-06',         'ITEM_NO'),
#             (     'B', 'Cm-06',       'ITEM_NAME'),
#             (     'B', 'Cm-06',           'STOCK'),
#             (     'B', 'Cm-06',            'SALE'),
#             (     'B', 'Cm-07',         'ITEM_NO'),
#             (     'B', 'Cm-07',       'ITEM_NAME'),
#             (     'B', 'Cm-07',           'STOCK'),
#             (     'B', 'Cm-07',            'SALE'),
#             (     'B', 'Cm-08',         'ITEM_NO'),
#             (     'B', 'Cm-08',       'ITEM_NAME'),
#             (     'B', 'Cm-08',           'STOCK'),
#             (     'B', 'Cm-08',            'SALE'),
#             (     'C', 'Cm-09',         'ITEM_NO'),
#             (     'C', 'Cm-09',       'ITEM_NAME'),
#             (     'C', 'Cm-09',           'STOCK'),
#             (     'C', 'Cm-09',            'SALE'),
#             (     'C', 'Cm-10',         'ITEM_NO'),
#             (     'C', 'Cm-10',       'ITEM_NAME'),
#             (     'C', 'Cm-10',           'STOCK'),
#             (     'C', 'Cm-10',            'SALE'),
#             (     'C', 'Cm-11',         'ITEM_NO'),
#             (     'C', 'Cm-11',       'ITEM_NAME'),
#             (     'C', 'Cm-11',           'STOCK'),
#             (     'C', 'Cm-11',            'SALE'),
#             (     'C', 'Cm-12',         'ITEM_NO'),
#             (     'C', 'Cm-12',       'ITEM_NAME'),
#             (     'C', 'Cm-12',           'STOCK'),
#             (     'C', 'Cm-12',            'SALE'),
#             (     'C', 'Cm-13',         'ITEM_NO'),
#             (     'C', 'Cm-13',       'ITEM_NAME'),
#             (     'C', 'Cm-13',           'STOCK'),
#             (     'C', 'Cm-13',            'SALE'),
#             ('A_Plus', 'Cm-01', 'Sale_Percentage'),
#             ('A_Plus', 'Cm-02', 'Sale_Percentage'),
#             ('A_Plus', 'Cm-03', 'Sale_Percentage'),
#             (     'A', 'Cm-04', 'Sale_Percentage'),
#             (     'A', 'Cm-05', 'Sale_Percentage'),
#             (     'B', 'Cm-06', 'Sale_Percentage'),
#             (     'B', 'Cm-07', 'Sale_Percentage'),
#             (     'B', 'Cm-08', 'Sale_Percentage'),
#             (     'C', 'Cm-09', 'Sale_Percentage'),
#             (     'C', 'Cm-10', 'Sale_Percentage'),
#             (     'C', 'Cm-11', 'Sale_Percentage'),
#             (     'C', 'Cm-12', 'Sale_Percentage'),
#             (     'C', 'Cm-13', 'Sale_Percentage')],
#            )

# %% [markdown]
# ### Standardizing the dataset

# %%
scaler = StandardScaler()

scaler.fit_transform(X_train)
# Out:
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# array([[ 0.        , -0.2773501 ,  0.4472136 , -0.76249285,  0.        ,
#          0.4472136 , -0.4472136 , -0.4472136 ,  0.        ,  1.52127766,
#         -0.4472136 , -0.63245553,  0.        ,  0.50709255,  0.4472136 ,
#          0.        ,  0.        , -0.63245553, -0.4472136 ,  0.4472136 ,
#         -0.11547005,  0.16903085, -0.30151134, -0.16903085,  0.        ,
#          1.18321596, -0.16903085, -0.33333333,  0.        ,  0.16903085,
#          0.4472136 ,  0.50709255,  0.        , -0.50709255,  0.4472136 ,
#         -0.90453403,  0.        ,  0.4472136 , -0.4472136 , -0.63245553,
#          0.        ,  1.18321596,  0.4472136 , -0.90453403,  0.        ,
#         -0.4472136 , -0.4472136 , -1.34164079,  0.        ,  0.50709255,
#         -0.4472136 ,  0.90453403],
#        [-1.60356745, -1.38675049,  1.34164079, -0.76249285, -1.60356745,
#         -1.34164079,  0.4472136 , -1.34164079, -1.60356745, -1.18321596,
#          0.4472136 , -1.26491106, -1.60356745, -1.52127766,  1.34164079,
#          1.41421356, -1.60356745, -1.26491106,  0.4472136 , -0.4472136 ,
#         -1.5011107 , -1.18321596,  0.90453403, -1.52127766, -1.60356745,
#         -0.16903085,  0.50709255, -0.33333333, -1.60356745, -1.18321596,
#          1.34164079, -1.52127766, -1.60356745,  0.16903085,  1.34164079,
#         -0.90453403, -1.60356745, -1.34164079,  0.4472136 , -1.26491106,
#         -1.60356745, -1.52127766,  1.34164079, -0.90453403, -1.60356745,
#          1.34164079,  0.4472136 , -0.4472136 , -1.60356745, -1.52127766,
#          0.4472136 , -0.30151134],
#        [ 1.06904497,  0.2773501 , -0.4472136 , -0.15249857,  1.06904497,
#          1.34164079,  1.34164079,  0.4472136 ,  1.06904497, -0.50709255,
#          1.34164079,  0.63245553,  1.06904497,  1.18321596, -0.4472136 ,
#          0.        ,  1.06904497,  0.63245553,  1.34164079, -1.34164079,
#          1.27017059,  1.52127766,  0.90453403,  0.50709255,  1.06904497,
#          0.50709255,  1.18321596, -1.        ,  1.06904497,  1.52127766,
#         -1.34164079, -0.16903085,  1.06904497, -1.18321596, -1.34164079,
#          1.50755672,  1.06904497,  1.34164079,  1.34164079,  0.63245553,
#          1.06904497,  0.50709255, -0.4472136 ,  1.50755672,  1.06904497,
#          0.4472136 ,  1.34164079,  0.4472136 ,  1.06904497,  1.18321596,
#          1.34164079,  0.90453403],
#        [ 0.53452248,  1.38675049, -1.34164079,  1.67748427,  0.53452248,
#         -0.4472136 , -1.34164079,  1.34164079,  0.53452248,  0.16903085,
#         -1.34164079,  1.26491106,  0.53452248, -0.16903085, -1.34164079,
#         -1.41421356,  0.53452248,  1.26491106, -1.34164079,  1.34164079,
#          0.34641016, -0.50709255, -1.50755672,  1.18321596,  0.53452248,
#         -1.52127766, -1.52127766,  1.66666667,  0.53452248, -0.50709255,
#         -0.4472136 ,  1.18321596,  0.53452248,  1.52127766, -0.4472136 ,
#          0.30151134,  0.53452248, -0.4472136 , -1.34164079,  1.26491106,
#          0.53452248, -0.16903085, -1.34164079,  0.30151134,  0.53452248,
#         -1.34164079, -1.34164079,  1.34164079,  0.53452248, -0.16903085,
#         -1.34164079, -1.50755672]])

# %%
X_test = scaler.transform(X_test)
# Out:
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %% [markdown]
# ## Algorithm_1 - Multiple Linear Regression Model

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# LinearRegression()

# %%
# y = mX + C - Linear Regression Model

# where, m-slope, c-intercept

# Finding y_intercept

c = regressor.intercept_
c
# Out:
# array([ 0.78920745, -0.81682395, -0.14336647,  3.19068552,  3.62486817,
#         3.97245302,  3.20268271, -1.07560544,  0.65335046, -0.37453146,
#         0.83626109,  3.19162083,  5.5583774 ])

# %%
#  slope

m = regressor.coef_
m
# Out:
# array([[ 2.51811998e-02,  1.77570198e-02, -1.53931111e-02,
#          1.90059007e-02,  2.51811998e-02,  9.78808869e-03,
#          1.97100305e-02,  1.53931111e-02,  2.51811998e-02,
#         -3.56086707e-02,  1.97100305e-02,  2.84223135e-02,
#          2.51811998e-02,  1.01597646e-02, -1.53931111e-02,
#         -2.36390871e-03,  2.51811998e-02,  2.84223135e-02,
#          1.97100305e-02, -1.97100305e-02,  3.62181694e-02,
#          2.08250583e-02,  8.67306090e-03,  1.57647870e-02,
#          2.51811998e-02, -1.82625489e-02,  1.77177977e-02,
#         -5.06027127e-03,  2.51811998e-02,  2.08250583e-02,
#         -2.44378479e-02, -7.92970905e-03,  2.51811998e-02,
#         -5.43194720e-03, -2.44378479e-02,  4.81323440e-02,
#          2.51811998e-02,  9.78808869e-03,  1.97100305e-02,
#          2.84223135e-02,  2.51811998e-02, -1.35347315e-02,
#         -1.53931111e-02,  2.40661720e-02,  2.51811998e-02,
#          8.30138498e-03,  1.97100305e-02,  2.76789616e-02,
#          2.51811998e-02,  1.01597646e-02,  1.97100305e-02,
#         -3.61278964e-03],
#        [ 2.95163813e-02, -1.42029595e-02,  1.55728271e-02,
#         -6.14118207e-02,  2.95163813e-02,  4.50892084e-02,
#         -5.60917290e-03, -1.55728271e-02,  2.95163813e-02,
#          1.00776680e-01, -5.60917290e-03, -3.25155218e-02,
#          2.95163813e-02,  6.12821180e-02,  1.55728271e-02,
#         -1.36986756e-03,  2.95163813e-02, -3.25155218e-02,
#         -5.60917290e-03,  5.60917290e-03,  2.73967287e-02,
#          4.29695558e-02, -3.48952023e-03,  6.20082454e-04,
#          2.95163813e-02,  9.37976398e-02,  9.21386909e-03,
#         -4.23494733e-02,  2.95163813e-02,  4.29695558e-02,
#          2.86943778e-03,  3.58753394e-02,  2.95163813e-02,
#         -5.85423829e-02,  2.86943778e-03, -3.81246947e-02,
#          2.95163813e-02,  4.50892084e-02, -5.60917290e-03,
#         -3.25155218e-02,  2.95163813e-02,  9.65373749e-02,
#          1.55728271e-02, -1.90623473e-02,  2.95163813e-02,
#         -1.96824298e-02, -5.60917290e-03, -6.49013409e-02,
#          2.95163813e-02,  6.12821180e-02, -5.60917290e-03,
#          4.58389936e-02],
#        [ 4.68257714e-02, -1.06007536e-02,  1.23099234e-02,
#         -6.63214293e-02,  4.68257714e-02,  5.91356947e-02,
#          5.12086835e-03, -1.23099234e-02,  4.68257714e-02,
#          1.01196294e-01,  5.12086835e-03, -2.63290164e-02,
#          4.68257714e-02,  7.82789765e-02,  1.23099234e-02,
#         -1.70916971e-03,  4.68257714e-02, -2.63290164e-02,
#          5.12086835e-03, -5.12086835e-03,  5.02407904e-02,
#          6.25507137e-02,  1.70584932e-03,  6.83335844e-03,
#          4.68257714e-02,  1.04607993e-01,  2.25549804e-02,
#         -5.57173553e-02,  4.68257714e-02,  6.25507137e-02,
#         -8.53920776e-03,  3.65807143e-02,  4.68257714e-02,
#         -7.48606371e-02, -8.53920776e-03, -2.12081481e-02,
#          4.68257714e-02,  5.91356947e-02,  5.12086835e-03,
#         -2.63290164e-02,  4.68257714e-02,  1.08026332e-01,
#          1.23099234e-02, -1.06040740e-02,  4.68257714e-02,
#         -1.74374325e-02,  5.12086835e-03, -6.46155800e-02,
#          4.68257714e-02,  7.82789765e-02,  5.12086835e-03,
#          5.40115060e-02],
#        [-2.75884811e-02, -5.26667488e-02,  3.74512785e-02,
#         -6.91329678e-02, -2.75884811e-02,  9.86279742e-03,
#          2.00862720e-03, -3.74512785e-02, -2.75884811e-02,
#          5.27427027e-02,  2.00862720e-03, -5.96870866e-02,
#         -2.75884811e-02,  1.02797136e-02,  3.74512785e-02,
#          1.52154704e-02, -2.75884811e-02, -5.96870866e-02,
#          2.00862720e-03, -2.00862720e-03, -3.41919027e-02,
#          3.25937584e-03,  8.61204877e-03, -3.70343623e-02,
#         -2.75884811e-02,  6.99668003e-02,  1.76410138e-02,
#         -4.02937381e-02, -2.75884811e-02,  3.25937584e-03,
#          2.84223135e-02, -7.77821635e-03, -2.75884811e-02,
#         -4.07106543e-02,  2.84223135e-02, -5.76784594e-02,
#         -2.75884811e-02,  9.86279742e-03,  2.00862720e-03,
#         -5.96870866e-02, -2.75884811e-02,  3.95358596e-02,
#          3.74512785e-02, -2.88392297e-02, -2.75884811e-02,
#          8.19513256e-03,  2.00862720e-03, -6.05209191e-02,
#         -2.75884811e-02,  1.02797136e-02,  2.00862720e-03,
#          3.16816893e-02],
#        [-1.84387370e-02, -1.48072702e-02,  2.43008819e-02,
#         -4.92965551e-02, -1.84387370e-02,  5.86214496e-03,
#         -6.67478917e-02, -2.43008819e-02, -1.84387370e-02,
#          1.54859990e-01, -6.67478917e-02, -5.80953757e-02,
#         -1.84387370e-02,  2.05231105e-02,  2.43008819e-02,
#         -9.49361178e-03, -1.84387370e-02, -5.80953757e-02,
#         -6.67478917e-02,  6.67478917e-02, -4.70658769e-02,
#         -2.27649950e-02, -3.81207517e-02, -9.63991638e-03,
#         -1.84387370e-02,  7.86184862e-02, -6.15805379e-02,
#          1.31250786e-02, -1.84387370e-02, -2.27649950e-02,
#          4.77606681e-02,  6.74426828e-02, -1.84387370e-02,
#         -1.53588696e-03,  4.77606681e-02, -1.24843267e-01,
#         -1.84387370e-02,  5.86214496e-03, -6.67478917e-02,
#         -5.80953757e-02, -1.84387370e-02,  9.76057097e-02,
#          2.43008819e-02, -6.24216337e-02, -1.84387370e-02,
#         -5.27817173e-02, -6.67478917e-02, -8.74173068e-02,
#         -1.84387370e-02,  2.05231105e-02, -6.67478917e-02,
#          2.49956731e-02],
#        [-5.82665832e-03,  6.29172016e-02, -4.19545547e-02,
#          1.04015719e-01, -5.82665832e-03, -4.77812130e-02,
#         -3.43280386e-02,  4.19545547e-02, -5.82665832e-03,
#         -6.21489468e-02, -3.43280386e-02,  6.29464625e-02,
#         -5.82665832e-03, -5.44931698e-02, -4.19545547e-02,
#         -2.09626469e-02, -5.82665832e-03,  6.29464625e-02,
#         -3.43280386e-02,  3.43280386e-02, -1.25093542e-02,
#         -5.44639088e-02, -2.76453427e-02,  3.52425979e-02,
#         -5.82665832e-03, -1.17439632e-01, -6.20026422e-02,
#          8.97065068e-02, -5.82665832e-03, -5.44639088e-02,
#         -7.59725520e-03,  1.42214292e-02, -5.82665832e-03,
#          9.64184635e-02, -7.59725520e-03,  2.86184239e-02,
#         -5.82665832e-03, -4.77812130e-02, -3.43280386e-02,
#          6.29464625e-02, -5.82665832e-03, -7.55143385e-02,
#         -4.19545547e-02,  1.43092120e-02, -5.82665832e-03,
#         -2.09333860e-02, -3.43280386e-02,  7.63703760e-02,
#         -5.82665832e-03, -5.44931698e-02, -3.43280386e-02,
#         -6.20611640e-02],
#        [-6.59387546e-03,  9.54985085e-03,  1.11100182e-02,
#         -2.79946060e-02, -6.59387546e-03,  4.51614269e-03,
#         -8.67164974e-02, -1.11100182e-02, -6.59387546e-03,
#          1.74173856e-01, -8.67164974e-02, -4.28799053e-02,
#         -6.59387546e-03,  2.39175847e-02,  1.11100182e-02,
#         -2.06598690e-02, -6.59387546e-03, -4.28799053e-02,
#         -8.67164974e-02,  8.67164974e-02, -3.96221897e-02,
#         -2.85121715e-02, -5.36881832e-02,  8.29142381e-03,
#         -6.59387546e-03,  6.67974900e-02, -8.79749244e-02,
#          3.68035953e-02, -6.59387546e-03, -2.85121715e-02,
#          4.53967594e-02,  9.24910671e-02, -6.59387546e-03,
#          1.74021534e-02,  4.53967594e-02, -1.29596403e-01,
#         -6.59387546e-03,  4.51614269e-03, -8.67164974e-02,
#         -4.28799053e-02, -6.59387546e-03,  1.08117228e-01,
#          1.11100182e-02, -6.47982013e-02, -6.59387546e-03,
#         -7.30896252e-02, -8.67164974e-02, -8.16827892e-02,
#         -6.59387546e-03,  2.39175847e-02, -8.67164974e-02,
#          1.68845879e-02],
#        [ 5.74669922e-02, -3.69849715e-03,  1.01481433e-02,
#         -7.00830138e-02,  5.74669922e-02,  6.76151355e-02,
#         -3.98840853e-03, -1.01481433e-02,  5.74669922e-02,
#          1.29077177e-01, -3.98840853e-03, -2.67459326e-02,
#          5.74669922e-02,  9.18931898e-02,  1.01481433e-02,
#         -6.44964611e-03,  5.74669922e-02, -2.67459326e-02,
#         -3.98840853e-03,  3.98840853e-03,  5.86976110e-02,
#          6.88457543e-02, -5.21902732e-03,  1.41299110e-02,
#          5.74669922e-02,  1.18639122e-01,  1.38399996e-02,
#         -5.47158433e-02,  5.74669922e-02,  6.88457543e-02,
#         -8.91088369e-03,  5.37751359e-02,  5.74669922e-02,
#         -7.89938975e-02, -8.91088369e-03, -3.07343412e-02,
#          5.74669922e-02,  6.76151355e-02, -3.98840853e-03,
#         -2.67459326e-02,  5.74669922e-02,  1.31538415e-01,
#          1.01481433e-02, -1.53671706e-02,  5.74669922e-02,
#         -2.94970816e-02, -3.98840853e-03, -7.53020412e-02,
#          5.74669922e-02,  9.18931898e-02, -3.98840853e-03,
#          5.99348706e-02],
#        [ 1.49021087e-02, -3.13075231e-02,  1.87952636e-02,
#         -5.50366758e-02,  1.49021087e-02,  3.36973724e-02,
#          3.24486990e-02, -1.87952636e-02,  1.49021087e-02,
#          1.75536461e-02,  3.24486990e-02, -2.50782678e-02,
#          1.49021087e-02,  3.74363367e-02,  1.87952636e-02,
#          1.25122595e-02,  1.49021087e-02, -2.50782678e-02,
#          3.24486990e-02, -3.24486990e-02,  2.48703285e-02,
#          4.36655921e-02,  2.24804792e-02, -1.50562993e-02,
#          1.49021087e-02,  6.25146045e-02,  4.86999228e-02,
#         -5.87218914e-02,  1.49021087e-02,  4.36655921e-02,
#         -7.42417998e-03, -1.50025505e-02,  1.49021087e-02,
#         -6.24608557e-02, -7.42417998e-03,  7.37043120e-03,
#          1.49021087e-02,  3.36973724e-02,  3.24486990e-02,
#         -2.50782678e-02,  1.49021087e-02,  3.74900855e-02,
#          1.87952636e-02,  3.68521560e-03,  1.49021087e-02,
#          1.87415149e-02,  3.24486990e-02, -3.25561965e-02,
#          1.49021087e-02,  3.74363367e-02,  3.24486990e-02,
#          3.62414121e-02],
#        [ 2.00788011e-02, -3.65035153e-03,  6.70552351e-03,
#         -3.25867026e-02,  2.00788011e-02,  2.67843246e-02,
#         -7.35922489e-03, -6.70552351e-03,  2.00788011e-02,
#          6.43287815e-02, -7.35922489e-03, -1.64662190e-02,
#          2.00788011e-02,  3.74481656e-02,  6.70552351e-03,
#         -3.05517198e-03,  2.00788011e-02, -1.64662190e-02,
#         -7.35922489e-03,  7.35922489e-03,  1.79267747e-02,
#          2.46322982e-02, -5.20719844e-03,  3.95831751e-03,
#          2.00788011e-02,  5.39143846e-02,  2.49444146e-04,
#         -2.06739807e-02,  2.00788011e-02,  2.46322982e-02,
#          1.24888093e-03,  2.65348805e-02,  2.00788011e-02,
#         -3.13378217e-02,  1.24888093e-03, -2.38254439e-02,
#          2.00788011e-02,  2.67843246e-02, -7.35922489e-03,
#         -1.64662190e-02,  2.00788011e-02,  6.00247286e-02,
#          6.70552351e-03, -1.19127219e-02,  2.00788011e-02,
#         -1.58710395e-02, -7.35922489e-03, -3.77939010e-02,
#          2.00788011e-02,  3.74481656e-02, -7.35922489e-03,
#          2.58811791e-02],
#        [-5.10239869e-03, -2.14073713e-02,  2.20986346e-02,
#         -5.15926033e-02, -5.10239869e-03,  1.69962359e-02,
#         -2.70692554e-02, -2.20986346e-02, -5.10239869e-03,
#          9.99374522e-02, -2.70692554e-02, -4.48885325e-02,
#         -5.10239869e-03,  2.72884010e-02,  2.20986346e-02,
#         -6.91263271e-04, -5.10239869e-03, -4.48885325e-02,
#         -2.70692554e-02,  2.70692554e-02, -1.82913948e-02,
#          3.80723986e-03, -1.38802593e-02, -1.18064695e-02,
#         -5.10239869e-03,  7.21769335e-02, -1.74683536e-02,
#         -1.56137094e-02, -5.10239869e-03,  3.80723986e-03,
#          2.56867289e-02,  3.44645895e-02, -5.10239869e-03,
#         -2.59058745e-02,  2.56867289e-02, -7.19577879e-02,
#         -5.10239869e-03,  1.69962359e-02, -2.70692554e-02,
#         -4.48885325e-02, -5.10239869e-03,  7.35594601e-02,
#          2.20986346e-02, -3.59788940e-02, -5.10239869e-03,
#         -2.41724244e-02, -2.70692554e-02, -6.54728627e-02,
#         -5.10239869e-03,  2.72884010e-02, -2.70692554e-02,
#          2.94939687e-02],
#        [-7.42936808e-05, -6.24980026e-03, -1.00088945e-02,
#          2.91426302e-02, -7.42936808e-05, -1.00831882e-02,
#          6.68771793e-02,  1.00088945e-02, -7.42936808e-05,
#         -1.46712588e-01,  6.68771793e-02,  3.62764837e-02,
#         -7.42936808e-05, -2.73002299e-02, -1.00088945e-02,
#          1.62586947e-02, -7.42936808e-05,  3.62764837e-02,
#          6.68771793e-02, -6.68771793e-02,  2.52349486e-02,
#          1.52260541e-02,  4.15679370e-02, -7.20814724e-03,
#         -7.42936808e-05, -6.35767136e-02,  6.59188323e-02,
#         -2.24342013e-02, -7.42936808e-05,  1.52260541e-02,
#         -3.43597898e-02, -7.60020205e-02, -7.42936808e-05,
#         -5.21715960e-03, -3.43597898e-02,  1.03153663e-01,
#         -7.42936808e-05, -1.00831882e-02,  6.68771793e-02,
#          3.62764837e-02, -7.42936808e-05, -9.60941031e-02,
#         -1.00088945e-02,  5.15768315e-02, -7.42936808e-05,
#          5.87849787e-02,  6.68771793e-02,  7.07105672e-02,
#         -7.42936808e-05, -2.73002299e-02,  6.68771793e-02,
#         -1.91337357e-02],
#        [-1.25691211e-02,  5.99674519e-02, -5.08623255e-02,
#          1.34306373e-01, -1.25691211e-02, -6.34314466e-02,
#          1.27098226e-02,  5.08623255e-02, -1.25691211e-02,
#         -1.81400266e-01,  1.27098226e-02,  9.26195246e-02,
#         -1.25691211e-02, -8.51760449e-02, -5.08623255e-02,
#         -9.10512639e-03, -1.25691211e-02,  9.26195246e-02,
#          1.27098226e-02, -1.27098226e-02, -1.66164666e-03,
#         -5.25239722e-02,  1.80234810e-03,  2.91177273e-02,
#         -1.25691211e-02, -1.77795570e-01, -1.81399021e-02,
#          8.16416994e-02, -1.25691211e-02, -5.25239722e-02,
#         -3.09200754e-02, -4.52915446e-02, -1.25691211e-02,
#          1.03386298e-01, -3.09200754e-02,  1.05329347e-01,
#         -1.25691211e-02, -6.34314466e-02,  1.27098226e-02,
#          9.26195246e-02, -1.25691211e-02, -1.59585317e-01,
#         -5.08623255e-02,  5.26646736e-02, -1.25691211e-02,
#          2.35469463e-02,  1.27098226e-02,  1.36108721e-01,
#         -1.25691211e-02, -8.51760449e-02,  1.27098226e-02,
#         -8.34440475e-02]])

# %%
y_prediction = regressor.predict(X_test)
# Out:
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %%
y_prediction
# Out:
# array([[ 3.70025177,  2.62587674,  5.38717176,  0.98202446,  0.54309698,
#          1.65424738,  0.68315903,  5.36837193,  3.44357125,  1.80353845,
#          0.10328669,  4.53674611,  3.41089863],
#        [ 1.6311132 , -0.08032849,  1.16564378,  2.69453178,  2.33180014,
#          3.1507012 ,  1.8669865 ,  0.36365263,  1.57161724,  0.05884018,
#          0.42772698,  4.08505008,  5.18778786],
#        [ 1.85480047,  0.08555332,  1.40866796,  1.72266563,  2.79848628,
#          4.34237205,  3.01244896,  0.9113637 ,  0.90058074,  0.29412453,
#          0.43932406,  3.16713214,  5.6890853 ]])

# %%
plt.scatter(y_test, y_prediction)
plt.xlabel("Actual Sale_Percentage")
plt.ylabel("Predicted Sale_Percentage")
plt.show()

# %% [markdown]
# # Accuracy Score

# %% [markdown]
# ### R2_Score

# %%
score = r2_score(y_test, y_prediction)
score 


# Expected Score is 0.9 to 1.0
# Out:
# -2.6558156710880216

# %%
y_prediction_train = regressor.predict(X_train)
y_prediction_train
# Out:
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(
# array([[ 2.00000000e+00,  3.00000000e+00,  5.00000000e+00,
#          3.00000000e+00,  4.00000000e+00,  1.00000000e+00,
#          4.00000000e+00,  5.00000000e+00,  3.00000000e+00,
#          2.00000000e+00,  2.00000000e+00,  2.00000000e+00,
#          1.00000000e+00],
#        [ 1.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          4.00000000e+00,  3.00000000e+00,  2.00000000e+00,
#          2.00000000e+00,  6.66133815e-16,  2.00000000e+00,
#         -7.21644966e-16,  1.00000000e+00,  4.00000000e+00,
#          4.00000000e+00],
#        [ 4.00000000e+00,  3.00000000e+00,  6.00000000e+00,
#          1.00000000e+00,  1.33226763e-15,  1.00000000e+00,
#          2.66453526e-15,  6.00000000e+00,  4.00000000e+00,
#          2.00000000e+00,  6.66133815e-16,  5.00000000e+00,
#          3.00000000e+00],
#        [ 3.00000000e+00,  1.00000000e+00,  3.00000000e+00,
#         -2.66453526e-15,  2.00000000e+00,  5.00000000e+00,
#          3.00000000e+00,  3.00000000e+00,  1.00000000e+00,
#          1.00000000e+00, -5.55111512e-16,  3.00000000e+00,
#          6.00000000e+00]])

# %%
plt.scatter(y_train, y_prediction_train)
plt.xlabel("Actual Sale_Percentage")
plt.ylabel("Predicted Sale_Percentage")
plt.show()

# %%
score = r2_score(y_train, y_prediction_train)
score
# Out:
# 1.0

# %% [markdown]
# # Algorithm_2 - Random Forest Regressor

# %%
rf = RandomForestRegressor(n_estimators=30, random_state=30)

# %%
rf_model = rf.fit(X_train, y_train)
# Out:
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %%
print('r2_score: %.2f'% rf_model.score(X_train, y_train))
# Out:
# r2_score: 0.81
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %% [markdown]
# ## Prediction

# %%
ytrain_pred = rf_model.predict(X_train)
# Out:
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %% [markdown]
# ### Mean Absolute Error

# %%
print('Mean Absolute Error: %.2f'% mean_absolute_error(y_train, ytrain_pred))
# Out:
# Mean Absolute Error: 0.53

# %% [markdown]
# ### Mean Squared Error

# %%
print('Mean Squared Error: %.2f'% mean_squared_error(y_train, ytrain_pred))
# Out:
# Mean Squared Error: 0.42

# %% [markdown]
# ### Root Mean Square Error

# %%
print('RMSE : ', np.sqrt(mean_squared_error(y_train, ytrain_pred)))
# Out:
# RMSE :  0.6457950774442942

# %% [markdown]
# ### Explained Variance Score

# %%
print('EVS: %.2f'% explained_variance_score(y_train, ytrain_pred))
# Out:
# EVS: 0.82

# %% [markdown]
# ### Prediction on testing data

# %%
ytest_pred = rf_model.predict(X_test)
# Out:
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %%
ytest_pred
# Out:
# array([[2.96666667, 2.33333333, 4.66666667, 1.56666667, 1.86666667,
#         2.        , 2.03333333, 4.6       , 2.86666667, 1.63333333,
#         0.66666667, 3.56666667, 3.16666667],
#        [1.93333333, 1.43333333, 3.1       , 2.6       , 3.03333333,
#         2.3       , 2.9       , 2.73333333, 2.2       , 1.03333333,
#         1.1       , 3.06666667, 3.33333333],
#        [2.3       , 1.9       , 3.83333333, 2.3       , 2.7       ,
#         2.03333333, 2.66666667, 3.6       , 2.53333333, 1.33333333,
#         1.03333333, 3.16666667, 3.03333333]])

# %%
print('r2_score: %.2f'% r2_score(y_test, ytest_pred))

# or

print('r2_score: %.2f'% rf_model.score(X_test, y_test))
# Out:
# r2_score: -1.14
# r2_score: -1.14
# C:\Users\deepa\Miniconda3\lib\site-packages\sklearn\utils\validation.py:1688: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['tuple']. An error will be raised in 1.2.
#   warnings.warn(

# %%
print('Mean Absolute Error: %.2f'% mean_absolute_error(y_test, ytest_pred))
print('Mean Squared Error: %.2f'% mean_squared_error(y_test, ytest_pred))
print('RMSE : ', np.sqrt(mean_squared_error(y_test, ytest_pred)))
print('EVS: %.2f'% explained_variance_score(y_test, ytest_pred))
# Out:
# Mean Absolute Error: 1.75
# Mean Squared Error: 4.19
# RMSE :  2.0467332041858337
# EVS: -0.09

# %% [markdown]
# ## Sales in percentage

# %%
data
# Out:
#        A_Plus                                                              \
#         Cm-01                                               Cm-02
#          DATE ITEM_NO            ITEM_NAME STOCK SALE        DATE ITEM_NO
# 0  01-07-2023   11101     Apple 14 Pro Max     5    1  01-07-2023   11106
# 1  02-07-2023   11102         Vivo 15 Plus    10    8  02-07-2023   11107
# 2  03-07-2023   11103     Apple 13 Pro Max     4    0  03-07-2023   11108
# 3  04-07-2023   11104  Oppo Reno 10 Series     4    1  04-07-2023   11109
# 4  05-07-2023   11105          samsung S23    12    9  05-07-2023   11110
# 5  06-07-2023   15786           Realme C52    14   11  06-07-2023   11789
# 6  07-07-2023   15787       OnePlus Nord 3     8    6  07-07-2023   12346
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 0     Apple 14 Pro Max     5    0  ...       60.000000       40.000000
# 1        Apple 14 Plus    10    4  ...       60.000000       90.000000
# 2     Apple 13 Pro Max     4    3  ...       50.000000       25.000000
# 3  Oppo Reno 10 Series     4    2  ...       50.000000       75.000000
# 4  Oppo Reno 09 series    12    4  ...      100.000000       33.333333
# 5         Realme 11Pro     6    3  ...       13.333333       12.500000
# 6           Realme C52     8    4  ...       42.857143       77.777778
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0            20.0       40.000000        0.000000       40.000000
# 1            40.0       40.000000       40.000000       30.000000
# 2            50.0       75.000000       25.000000       50.000000
# 3           100.0       50.000000       50.000000       50.000000
# 4            75.0       41.666667       33.333333       33.333333
# 5           100.0        0.000000       90.909091       60.000000
# 6             0.0       13.333333      100.000000       62.500000
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0       20.000000            40.0       80.000000       60.000000
# 1       20.000000            50.0       80.000000       90.000000
# 2       75.000000            75.0       25.000000       25.000000
# 3       50.000000            50.0       50.000000      100.000000
# 4       41.666667            25.0       66.666667       91.666667
# 5       50.000000            25.0       85.714286       50.000000
# 6       66.666667            90.0       14.285714        0.000000
#
# [7 rows x 78 columns]

# %%
for store in data.columns.get_level_values(0).unique():
    for cm in data.columns.get_level_values(1).unique():
        try:
            sale_data = data.loc[:, (store, cm, 'SALE')]
            stock_data = data.loc[:, (store, cm, 'STOCK')]
            data[(store, cm, 'Sale_Percentage')] = (sale_data / stock_data) * 100
            data[(store, cm, 'Sale_Percentage')] = data[(store, cm, 'Sale_Percentage')].round(0).astype(int).astype(str) + '%'
        except KeyError:
            pass

print(data)
# Out:
#        A_Plus                                                              \
#         Cm-01                                               Cm-02
#          DATE ITEM_NO            ITEM_NAME STOCK SALE        DATE ITEM_NO
# 0  01-07-2023   11101     Apple 14 Pro Max     5    1  01-07-2023   11106
# 1  02-07-2023   11102         Vivo 15 Plus    10    8  02-07-2023   11107
# 2  03-07-2023   11103     Apple 13 Pro Max     4    0  03-07-2023   11108
# 3  04-07-2023   11104  Oppo Reno 10 Series     4    1  04-07-2023   11109
# 4  05-07-2023   11105          samsung S23    12    9  05-07-2023   11110
# 5  06-07-2023   15786           Realme C52    14   11  06-07-2023   11789
# 6  07-07-2023   15787       OnePlus Nord 3     8    6  07-07-2023   12346
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 0     Apple 14 Pro Max     5    0  ...             60%             40%
# 1        Apple 14 Plus    10    4  ...             60%             90%
# 2     Apple 13 Pro Max     4    3  ...             50%             25%
# 3  Oppo Reno 10 Series     4    2  ...             50%             75%
# 4  Oppo Reno 09 series    12    4  ...            100%             33%
# 5         Realme 11Pro     6    3  ...             13%             12%
# 6           Realme C52     8    4  ...             43%             78%
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%              0%             40%
# 1             40%             40%             40%             30%
# 2             50%             75%             25%             50%
# 3            100%             50%             50%             50%
# 4             75%             42%             33%             33%
# 5            100%              0%             91%             60%
# 6              0%             13%            100%             62%
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%             80%             60%
# 1             20%             50%             80%             90%
# 2             75%             75%             25%             25%
# 3             50%             50%             50%            100%
# 4             42%             25%             67%             92%
# 5             50%             25%             86%             50%
# 6             67%             90%             14%              0%
#
# [7 rows x 78 columns]

# %% [markdown]
# ## Converting DATE object to date format

# %%
for column in data.columns:
    if column[-1] == 'DATE':
        data[column] = pd.to_datetime(data[column])

print(data)
# Out:
#       A_Plus                                                             \
#        Cm-01                                              Cm-02
#         DATE ITEM_NO            ITEM_NAME STOCK SALE       DATE ITEM_NO
# 0 2023-01-07   11101     Apple 14 Pro Max     5    1 2023-01-07   11106
# 1 2023-02-07   11102         Vivo 15 Plus    10    8 2023-02-07   11107
# 2 2023-03-07   11103     Apple 13 Pro Max     4    0 2023-03-07   11108
# 3 2023-04-07   11104  Oppo Reno 10 Series     4    1 2023-04-07   11109
# 4 2023-05-07   11105          samsung S23    12    9 2023-05-07   11110
# 5 2023-06-07   15786           Realme C52    14   11 2023-06-07   11789
# 6 2023-07-07   15787       OnePlus Nord 3     8    6 2023-07-07   12346
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 0     Apple 14 Pro Max     5    0  ...             60%             40%
# 1        Apple 14 Plus    10    4  ...             60%             90%
# 2     Apple 13 Pro Max     4    3  ...             50%             25%
# 3  Oppo Reno 10 Series     4    2  ...             50%             75%
# 4  Oppo Reno 09 series    12    4  ...            100%             33%
# 5         Realme 11Pro     6    3  ...             13%             12%
# 6           Realme C52     8    4  ...             43%             78%
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%              0%             40%
# 1             40%             40%             40%             30%
# 2             50%             75%             25%             50%
# 3            100%             50%             50%             50%
# 4             75%             42%             33%             33%
# 5            100%              0%             91%             60%
# 6              0%             13%            100%             62%
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%             80%             60%
# 1             20%             50%             80%             90%
# 2             75%             75%             25%             25%
# 3             50%             50%             50%            100%
# 4             42%             25%             67%             92%
# 5             50%             25%             86%             50%
# 6             67%             90%             14%              0%
#
# [7 rows x 78 columns]

# %%
final_data = pd.DataFrame()

# Iterate over each 'Cm-xx' group
for cm in data.columns.get_level_values(1).unique():
    # Extract the relevant columns for each 'Cm-xx' group
    cm_data = data.loc[:, (slice(None), cm, slice(None))]

    # Get the 'Sale_Percentage' columns for the current 'Cm-xx' group
    sale_percentage_cols = cm_data.filter(like='Sale_Percentage')

    # Concatenate the original DataFrame with the 'Sale_Percentage' columns for the current 'Cm-xx' group
    cm_data_aligned = pd.concat([cm_data.drop(sale_percentage_cols, axis=1), sale_percentage_cols], axis=1)

    # Append the aligned data for the current 'Cm-xx' group to the final result DataFrame
    final_data = pd.concat([final_data, cm_data_aligned], axis=1)

print(final_data)
# Out:
#       A_Plus                                                          \
#        Cm-01
#         DATE ITEM_NO            ITEM_NAME STOCK SALE Sale_Percentage
# 0 2023-01-07   11101     Apple 14 Pro Max     5    1             20%
# 1 2023-02-07   11102         Vivo 15 Plus    10    8             80%
# 2 2023-03-07   11103     Apple 13 Pro Max     4    0              0%
# 3 2023-04-07   11104  Oppo Reno 10 Series     4    1             25%
# 4 2023-05-07   11105          samsung S23    12    9             75%
# 5 2023-06-07   15786           Realme C52    14   11             79%
# 6 2023-07-07   15787       OnePlus Nord 3     8    6             75%
#
#                                                  ...                    C  \
#        Cm-02                                     ...                Cm-12
#         DATE ITEM_NO            ITEM_NAME STOCK  ...            ITEM_NAME
# 0 2023-01-07   11106     Apple 14 Pro Max     5  ...                Redmi
# 1 2023-02-07   11107        Apple 14 Plus    10  ...         Vivo 15 Plus
# 2 2023-03-07   11108     Apple 13 Pro Max     4  ...     Apple 13 Pro Max
# 3 2023-04-07   11109  Oppo Reno 10 Series     4  ...  Oppo Reno 10 Series
# 4 2023-05-07   11110  Oppo Reno 09 series    12  ...  Oppo Reno 09 series
# 5 2023-06-07   11789         Realme 11Pro     6  ...         Realme 11Pro
# 6 2023-07-07   12346           Realme C52     8  ...   Samsung Galaxy F54
#
#                                                                             \
#                                   Cm-13
#   STOCK SALE Sale_Percentage       DATE ITEM_NO            ITEM_NAME STOCK
# 0     5    4             80% 2023-01-07   11161     Apple 14 Pro Max     5
# 1    10    8             80% 2023-02-07   11162        Apple 14 Plus    10
# 2     4    1             25% 2023-03-07   11163     Apple 13 Pro Max     4
# 3     4    2             50% 2023-04-07   11164  Oppo Reno 10 Series     4
# 4    12    8             67% 2023-05-07   11165  Oppo Reno 09 series    12
# 5     7    6             86% 2023-06-07   11639           Realme C52     8
# 6     7    1             14% 2023-07-07   11640       OnePlus Nord 3     5
#
#
#
#   SALE Sale_Percentage
# 0    3             60%
# 1    9             90%
# 2    1             25%
# 3    4            100%
# 4   11             92%
# 5    4             50%
# 6    0              0%
#
# [7 rows x 78 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 78 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   (A_Plus, Cm-01, DATE)             7 non-null      datetime64[ns]
#  1   (A_Plus, Cm-01, ITEM_NO)          7 non-null      int64
#  2   (A_Plus, Cm-01, ITEM_NAME)        7 non-null      object
#  3   (A_Plus, Cm-01, STOCK)            7 non-null      int64
#  4   (A_Plus, Cm-01, SALE)             7 non-null      int64
#  5   (A_Plus, Cm-02, DATE)             7 non-null      datetime64[ns]
#  6   (A_Plus, Cm-02, ITEM_NO)          7 non-null      int64
#  7   (A_Plus, Cm-02, ITEM_NAME)        7 non-null      object
#  8   (A_Plus, Cm-02, STOCK)            7 non-null      int64
#  9   (A_Plus, Cm-02, SALE)             7 non-null      int64
#  10  (A_Plus, Cm-03, DATE)             7 non-null      datetime64[ns]
#  11  (A_Plus, Cm-03, ITEM_NO)          7 non-null      int64
#  12  (A_Plus, Cm-03, ITEM_NAME)        7 non-null      object
#  13  (A_Plus, Cm-03, STOCK)            7 non-null      int64
#  14  (A_Plus, Cm-03, SALE)             7 non-null      int64
#  15  (A, Cm-04, DATE)                  7 non-null      datetime64[ns]
#  16  (A, Cm-04, ITEM_NO)               7 non-null      int64
#  17  (A, Cm-04, ITEM_NAME)             7 non-null      object
#  18  (A, Cm-04, STOCK)                 7 non-null      int64
#  19  (A, Cm-04, SALE)                  7 non-null      int64
#  20  (A, Cm-05, DATE)                  7 non-null      datetime64[ns]
#  21  (A, Cm-05, ITEM_NO)               7 non-null      int64
#  22  (A, Cm-05, ITEM_NAME)             7 non-null      object
#  23  (A, Cm-05, STOCK)                 7 non-null      int64
#  24  (A, Cm-05, SALE)                  7 non-null      int64
#  25  (B, Cm-06, DATE)                  7 non-null      datetime64[ns]
#  26  (B, Cm-06, ITEM_NO)               7 non-null      int64
#  27  (B, Cm-06, ITEM_NAME)             7 non-null      object
#  28  (B, Cm-06, STOCK)                 7 non-null      int64
#  29  (B, Cm-06, SALE)                  7 non-null      int64
#  30  (B, Cm-07, DATE)                  7 non-null      datetime64[ns]
#  31  (B, Cm-07, ITEM_NO)               7 non-null      int64
#  32  (B, Cm-07, ITEM_NAME)             7 non-null      object
#  33  (B, Cm-07, STOCK)                 7 non-null      int64
#  34  (B, Cm-07, SALE)                  7 non-null      int64
#  35  (B, Cm-08, DATE)                  7 non-null      datetime64[ns]
#  36  (B, Cm-08, ITEM_NO)               7 non-null      int64
#  37  (B, Cm-08, ITEM_NAME)             7 non-null      object
#  38  (B, Cm-08, STOCK)                 7 non-null      int64
#  39  (B, Cm-08, SALE)                  7 non-null      int64
#  40  (C, Cm-09, DATE)                  7 non-null      datetime64[ns]
#  41  (C, Cm-09, ITEM_NO)               7 non-null      int64
#  42  (C, Cm-09, ITEM_NAME)             7 non-null      object
#  43  (C, Cm-09, STOCK)                 7 non-null      int64
#  44  (C, Cm-09, SALE)                  7 non-null      int64
#  45  (C, Cm-10, DATE)                  7 non-null      datetime64[ns]
#  46  (C, Cm-10, ITEM_NO)               7 non-null      int64
#  47  (C, Cm-10, ITEM_NAME)             7 non-null      object
#  48  (C, Cm-10, STOCK)                 7 non-null      int64
#  49  (C, Cm-10, SALE)                  7 non-null      int64
#  50  (C, Cm-11, DATE)                  7 non-null      datetime64[ns]
#  51  (C, Cm-11, ITEM_NO)               7 non-null      int64
#  52  (C, Cm-11, ITEM_NAME)             7 non-null      object
#  53  (C, Cm-11, STOCK)                 7 non-null      int64
#  54  (C, Cm-11, SALE)                  7 non-null      int64
#  55  (C, Cm-12, DATE)                  7 non-null      datetime64[ns]
#  56  (C, Cm-12, ITEM_NO)               7 non-null      int64
#  57  (C, Cm-12, ITEM_NAME)             7 non-null      object
#  58  (C, Cm-12, STOCK)                 7 non-null      int64
#  59  (C, Cm-12, SALE)                  7 non-null      int64
#  60  (C, Cm-13, DATE)                  7 non-null      datetime64[ns]
#  61  (C, Cm-13, ITEM_NO)               7 non-null      int64
#  62  (C, Cm-13, ITEM_NAME)             7 non-null      object
#  63  (C, Cm-13, STOCK)                 7 non-null      int64
#  64  (C, Cm-13, SALE)                  7 non-null      int64
#  65  (A_Plus, Cm-01, Sale_Percentage)  7 non-null      object
#  66  (A_Plus, Cm-02, Sale_Percentage)  7 non-null      object
#  67  (A_Plus, Cm-03, Sale_Percentage)  7 non-null      object
#  68  (A, Cm-04, Sale_Percentage)       7 non-null      object
#  69  (A, Cm-05, Sale_Percentage)       7 non-null      object
#  70  (B, Cm-06, Sale_Percentage)       7 non-null      object
#  71  (B, Cm-07, Sale_Percentage)       7 non-null      object
#  72  (B, Cm-08, Sale_Percentage)       7 non-null      object
#  73  (C, Cm-09, Sale_Percentage)       7 non-null      object
#  74  (C, Cm-10, Sale_Percentage)       7 non-null      object
#  75  (C, Cm-11, Sale_Percentage)       7 non-null      object
#  76  (C, Cm-12, Sale_Percentage)       7 non-null      object
#  77  (C, Cm-13, Sale_Percentage)       7 non-null      object
# dtypes: datetime64[ns](13), int64(39), object(26)
# memory usage: 4.4+ KB

# %%
data
# Out:
#       A_Plus                                                             \
#        Cm-01                                              Cm-02
#         DATE ITEM_NO            ITEM_NAME STOCK SALE       DATE ITEM_NO
# 0 2023-01-07   11101     Apple 14 Pro Max     5    1 2023-01-07   11106
# 1 2023-02-07   11102         Vivo 15 Plus    10    8 2023-02-07   11107
# 2 2023-03-07   11103     Apple 13 Pro Max     4    0 2023-03-07   11108
# 3 2023-04-07   11104  Oppo Reno 10 Series     4    1 2023-04-07   11109
# 4 2023-05-07   11105          samsung S23    12    9 2023-05-07   11110
# 5 2023-06-07   15786           Realme C52    14   11 2023-06-07   11789
# 6 2023-07-07   15787       OnePlus Nord 3     8    6 2023-07-07   12346
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 0     Apple 14 Pro Max     5    0  ...             60%             40%
# 1        Apple 14 Plus    10    4  ...             60%             90%
# 2     Apple 13 Pro Max     4    3  ...             50%             25%
# 3  Oppo Reno 10 Series     4    2  ...             50%             75%
# 4  Oppo Reno 09 series    12    4  ...            100%             33%
# 5         Realme 11Pro     6    3  ...             13%             12%
# 6           Realme C52     8    4  ...             43%             78%
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%              0%             40%
# 1             40%             40%             40%             30%
# 2             50%             75%             25%             50%
# 3            100%             50%             50%             50%
# 4             75%             42%             33%             33%
# 5            100%              0%             91%             60%
# 6              0%             13%            100%             62%
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%             80%             60%
# 1             20%             50%             80%             90%
# 2             75%             75%             25%             25%
# 3             50%             50%             50%            100%
# 4             42%             25%             67%             92%
# 5             50%             25%             86%             50%
# 6             67%             90%             14%              0%
#
# [7 rows x 78 columns]

# %% [markdown]
# ## Visualize weekly sales

# %%
plt.figure(figsize=(15,5))
plt.plot(data[("A_Plus", "Cm-01", "DATE")], data[("A_Plus", "Cm-01", "SALE")] )
plt.xlabel("Date")
plt.ylabel("Sale")
plt.title("Monthly sales")
plt.show()

# %%
# convert_csv = 'output_data.csv'  
# data.to_csv(convert_csv, index=False)

# %%
final_data = pd.DataFrame()


for cm in data.columns.get_level_values(1).unique():
    
    cm_data = data.loc[:, (slice(None), cm, slice(None))]

    
    sale_percentage_cols = cm_data.filter(like='Sale_Percentage')

    
    cm_data_aligned = pd.concat([cm_data.drop(sale_percentage_cols, axis=1), sale_percentage_cols], axis=1)

    
    final_data = pd.concat([final_data, cm_data_aligned], axis=1)

print(final_data)
# Out:
#       A_Plus                                                          \
#        Cm-01
#         DATE ITEM_NO            ITEM_NAME STOCK SALE Sale_Percentage
# 0 2023-01-07   11101     Apple 14 Pro Max     5    1             20%
# 1 2023-02-07   11102         Vivo 15 Plus    10    8             80%
# 2 2023-03-07   11103     Apple 13 Pro Max     4    0              0%
# 3 2023-04-07   11104  Oppo Reno 10 Series     4    1             25%
# 4 2023-05-07   11105          samsung S23    12    9             75%
# 5 2023-06-07   15786           Realme C52    14   11             79%
# 6 2023-07-07   15787       OnePlus Nord 3     8    6             75%
#
#                                                  ...                    C  \
#        Cm-02                                     ...                Cm-12
#         DATE ITEM_NO            ITEM_NAME STOCK  ...            ITEM_NAME
# 0 2023-01-07   11106     Apple 14 Pro Max     5  ...                Redmi
# 1 2023-02-07   11107        Apple 14 Plus    10  ...         Vivo 15 Plus
# 2 2023-03-07   11108     Apple 13 Pro Max     4  ...     Apple 13 Pro Max
# 3 2023-04-07   11109  Oppo Reno 10 Series     4  ...  Oppo Reno 10 Series
# 4 2023-05-07   11110  Oppo Reno 09 series    12  ...  Oppo Reno 09 series
# 5 2023-06-07   11789         Realme 11Pro     6  ...         Realme 11Pro
# 6 2023-07-07   12346           Realme C52     8  ...   Samsung Galaxy F54
#
#                                                                             \
#                                   Cm-13
#   STOCK SALE Sale_Percentage       DATE ITEM_NO            ITEM_NAME STOCK
# 0     5    4             80% 2023-01-07   11161     Apple 14 Pro Max     5
# 1    10    8             80% 2023-02-07   11162        Apple 14 Plus    10
# 2     4    1             25% 2023-03-07   11163     Apple 13 Pro Max     4
# 3     4    2             50% 2023-04-07   11164  Oppo Reno 10 Series     4
# 4    12    8             67% 2023-05-07   11165  Oppo Reno 09 series    12
# 5     7    6             86% 2023-06-07   11639           Realme C52     8
# 6     7    1             14% 2023-07-07   11640       OnePlus Nord 3     5
#
#
#
#   SALE Sale_Percentage
# 0    3             60%
# 1    9             90%
# 2    1             25%
# 3    4            100%
# 4   11             92%
# 5    4             50%
# 6    0              0%
#
# [7 rows x 78 columns]

# %%
print(data['A_Plus','Cm-01'])
print(data['A_Plus','Cm-02'])
# Out:
#         DATE  ITEM_NO            ITEM_NAME  STOCK  SALE Sale_Percentage
# 0 2023-01-07    11101     Apple 14 Pro Max      5     1             20%
# 1 2023-02-07    11102         Vivo 15 Plus     10     8             80%
# 2 2023-03-07    11103     Apple 13 Pro Max      4     0              0%
# 3 2023-04-07    11104  Oppo Reno 10 Series      4     1             25%
# 4 2023-05-07    11105          samsung S23     12     9             75%
# 5 2023-06-07    15786           Realme C52     14    11             79%
# 6 2023-07-07    15787       OnePlus Nord 3      8     6             75%
#         DATE  ITEM_NO            ITEM_NAME  STOCK  SALE Sale_Percentage
# 0 2023-01-07    11106     Apple 14 Pro Max      5     0              0%
# 1 2023-02-07    11107        Apple 14 Plus     10     4             40%
# 2 2023-03-07    11108     Apple 13 Pro Max      4     3             75%
# 3 2023-04-07    11109  Oppo Reno 10 Series      4     2             50%
# 4 2023-05-07    11110  Oppo Reno 09 series     12     4             33%
# 5 2023-06-07    11789         Realme 11Pro      6     3             50%
# 6 2023-07-07    12346           Realme C52      8     4             50%
# C:\Users\deepa\AppData\Local\Temp\ipykernel_17260\2567161700.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   print(data['A_Plus','Cm-01'])
# C:\Users\deepa\AppData\Local\Temp\ipykernel_17260\2567161700.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   print(data['A_Plus','Cm-02'])

# %%
data
# Out:
#       A_Plus                                                             \
#        Cm-01                                              Cm-02
#         DATE ITEM_NO            ITEM_NAME STOCK SALE       DATE ITEM_NO
# 0 2023-01-07   11101     Apple 14 Pro Max     5    1 2023-01-07   11106
# 1 2023-02-07   11102         Vivo 15 Plus    10    8 2023-02-07   11107
# 2 2023-03-07   11103     Apple 13 Pro Max     4    0 2023-03-07   11108
# 3 2023-04-07   11104  Oppo Reno 10 Series     4    1 2023-04-07   11109
# 4 2023-05-07   11105          samsung S23    12    9 2023-05-07   11110
# 5 2023-06-07   15786           Realme C52    14   11 2023-06-07   11789
# 6 2023-07-07   15787       OnePlus Nord 3     8    6 2023-07-07   12346
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 0     Apple 14 Pro Max     5    0  ...             60%             40%
# 1        Apple 14 Plus    10    4  ...             60%             90%
# 2     Apple 13 Pro Max     4    3  ...             50%             25%
# 3  Oppo Reno 10 Series     4    2  ...             50%             75%
# 4  Oppo Reno 09 series    12    4  ...            100%             33%
# 5         Realme 11Pro     6    3  ...             13%             12%
# 6           Realme C52     8    4  ...             43%             78%
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%              0%             40%
# 1             40%             40%             40%             30%
# 2             50%             75%             25%             50%
# 3            100%             50%             50%             50%
# 4             75%             42%             33%             33%
# 5            100%              0%             91%             60%
# 6              0%             13%            100%             62%
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%             80%             60%
# 1             20%             50%             80%             90%
# 2             75%             75%             25%             25%
# 3             50%             50%             50%            100%
# 4             42%             25%             67%             92%
# 5             50%             25%             86%             50%
# 6             67%             90%             14%              0%
#
# [7 rows x 78 columns]

# %%
final_data
# Out:
#       A_Plus                                                          \
#        Cm-01
#         DATE ITEM_NO            ITEM_NAME STOCK SALE Sale_Percentage
# 0 2023-01-07   11101     Apple 14 Pro Max     5    1             20%
# 1 2023-02-07   11102         Vivo 15 Plus    10    8             80%
# 2 2023-03-07   11103     Apple 13 Pro Max     4    0              0%
# 3 2023-04-07   11104  Oppo Reno 10 Series     4    1             25%
# 4 2023-05-07   11105          samsung S23    12    9             75%
# 5 2023-06-07   15786           Realme C52    14   11             79%
# 6 2023-07-07   15787       OnePlus Nord 3     8    6             75%
#
#                                                  ...                    C  \
#        Cm-02                                     ...                Cm-12
#         DATE ITEM_NO            ITEM_NAME STOCK  ...            ITEM_NAME
# 0 2023-01-07   11106     Apple 14 Pro Max     5  ...                Redmi
# 1 2023-02-07   11107        Apple 14 Plus    10  ...         Vivo 15 Plus
# 2 2023-03-07   11108     Apple 13 Pro Max     4  ...     Apple 13 Pro Max
# 3 2023-04-07   11109  Oppo Reno 10 Series     4  ...  Oppo Reno 10 Series
# 4 2023-05-07   11110  Oppo Reno 09 series    12  ...  Oppo Reno 09 series
# 5 2023-06-07   11789         Realme 11Pro     6  ...         Realme 11Pro
# 6 2023-07-07   12346           Realme C52     8  ...   Samsung Galaxy F54
#
#                                                                             \
#                                   Cm-13
#   STOCK SALE Sale_Percentage       DATE ITEM_NO            ITEM_NAME STOCK
# 0     5    4             80% 2023-01-07   11161     Apple 14 Pro Max     5
# 1    10    8             80% 2023-02-07   11162        Apple 14 Plus    10
# 2     4    1             25% 2023-03-07   11163     Apple 13 Pro Max     4
# 3     4    2             50% 2023-04-07   11164  Oppo Reno 10 Series     4
# 4    12    8             67% 2023-05-07   11165  Oppo Reno 09 series    12
# 5     7    6             86% 2023-06-07   11639           Realme C52     8
# 6     7    1             14% 2023-07-07   11640       OnePlus Nord 3     5
#
#
#
#   SALE Sale_Percentage
# 0    3             60%
# 1    9             90%
# 2    1             25%
# 3    4            100%
# 4   11             92%
# 5    4             50%
# 6    0              0%
#
# [7 rows x 78 columns]

# %%
final_data.describe()
# Out:
#              A_Plus                                                           \
#               Cm-01                               Cm-02
#             ITEM_NO      STOCK       SALE       ITEM_NO      STOCK      SALE
# count      7.000000   7.000000   7.000000      7.000000   7.000000  7.000000
# mean   12441.142857   8.142857   5.142857  11382.142857   7.000000  2.857143
# std     2285.314379   4.017817   4.450789    495.031120   3.109126  1.463850
# min    11101.000000   4.000000   0.000000  11106.000000   4.000000  0.000000
# 25%    11102.500000   4.500000   1.000000  11107.500000   4.500000  2.500000
# 50%    11104.000000   8.000000   6.000000  11109.000000   6.000000  3.000000
# 75%    13445.500000  11.000000   8.500000  11449.500000   9.000000  4.000000
# max    15787.000000  14.000000  11.000000  12346.000000  12.000000  4.000000
#
#                                                      A  ...         C  \
#               Cm-03                              Cm-04  ...     Cm-10
#             ITEM_NO      STOCK      SALE       ITEM_NO  ...      SALE
# count      7.000000   7.000000  7.000000      7.000000  ...  7.000000
# mean   12776.285714   7.428571  4.571429  12421.000000  ...  3.285714
# std     2840.601445   3.154739  2.760262   2225.296535  ...  1.799471
# min    11111.000000   4.000000  1.000000  11116.000000  ...  1.000000
# 25%    11112.500000   4.500000  2.500000  11117.500000  ...  2.000000
# 50%    11114.000000   8.000000  4.000000  11119.000000  ...  3.000000
# 75%    14024.500000   9.500000  7.000000  13399.000000  ...  4.500000
# max    16935.000000  12.000000  8.000000  15679.000000  ...  6.000000
#
#                                                                              \
#               Cm-11                               Cm-12
#             ITEM_NO      STOCK       SALE       ITEM_NO     STOCK      SALE
# count      7.000000   7.000000   7.000000      7.000000   7.00000  7.000000
# mean   11159.714286  10.714286   5.428571  11163.857143   7.00000  4.285714
# std       11.542881   7.040698   5.682052     10.090071   3.05505  3.093773
# min    11151.000000   4.000000   2.000000  11156.000000   4.00000  1.000000
# 25%    11152.500000   4.500000   2.500000  11157.500000   4.50000  1.500000
# 50%    11154.000000  10.000000   3.000000  11159.000000   7.00000  4.000000
# 75%    11165.500000  16.000000   5.000000  11169.000000   8.50000  7.000000
# max    11177.000000  20.000000  18.000000  11179.000000  12.00000  8.000000
#
#
#               Cm-13
#             ITEM_NO      STOCK       SALE
# count      7.000000   7.000000   7.000000
# mean   11299.142857   6.857143   4.571429
# std      232.511956   3.184785   4.035556
# min    11161.000000   4.000000   0.000000
# 25%    11162.500000   4.500000   2.000000
# 50%    11164.000000   5.000000   4.000000
# 75%    11402.000000   9.000000   6.500000
# max    11640.000000  12.000000  11.000000
#
# [8 rows x 39 columns]

# %%
pd.DataFrame(final_data)
# Out:
#       A_Plus                                                          \
#        Cm-01
#         DATE ITEM_NO            ITEM_NAME STOCK SALE Sale_Percentage
# 0 2023-01-07   11101     Apple 14 Pro Max     5    1             20%
# 1 2023-02-07   11102         Vivo 15 Plus    10    8             80%
# 2 2023-03-07   11103     Apple 13 Pro Max     4    0              0%
# 3 2023-04-07   11104  Oppo Reno 10 Series     4    1             25%
# 4 2023-05-07   11105          samsung S23    12    9             75%
# 5 2023-06-07   15786           Realme C52    14   11             79%
# 6 2023-07-07   15787       OnePlus Nord 3     8    6             75%
#
#                                                  ...                    C  \
#        Cm-02                                     ...                Cm-12
#         DATE ITEM_NO            ITEM_NAME STOCK  ...            ITEM_NAME
# 0 2023-01-07   11106     Apple 14 Pro Max     5  ...                Redmi
# 1 2023-02-07   11107        Apple 14 Plus    10  ...         Vivo 15 Plus
# 2 2023-03-07   11108     Apple 13 Pro Max     4  ...     Apple 13 Pro Max
# 3 2023-04-07   11109  Oppo Reno 10 Series     4  ...  Oppo Reno 10 Series
# 4 2023-05-07   11110  Oppo Reno 09 series    12  ...  Oppo Reno 09 series
# 5 2023-06-07   11789         Realme 11Pro     6  ...         Realme 11Pro
# 6 2023-07-07   12346           Realme C52     8  ...   Samsung Galaxy F54
#
#                                                                             \
#                                   Cm-13
#   STOCK SALE Sale_Percentage       DATE ITEM_NO            ITEM_NAME STOCK
# 0     5    4             80% 2023-01-07   11161     Apple 14 Pro Max     5
# 1    10    8             80% 2023-02-07   11162        Apple 14 Plus    10
# 2     4    1             25% 2023-03-07   11163     Apple 13 Pro Max     4
# 3     4    2             50% 2023-04-07   11164  Oppo Reno 10 Series     4
# 4    12    8             67% 2023-05-07   11165  Oppo Reno 09 series    12
# 5     7    6             86% 2023-06-07   11639           Realme C52     8
# 6     7    1             14% 2023-07-07   11640       OnePlus Nord 3     5
#
#
#
#   SALE Sale_Percentage
# 0    3             60%
# 1    9             90%
# 2    1             25%
# 3    4            100%
# 4   11             92%
# 5    4             50%
# 6    0              0%
#
# [7 rows x 78 columns]

# %%
# convert_csv = 'output_data_2.csv'  
# data.to_csv(convert_csv, index=False)

# %%
data
# Out:
#       A_Plus                                                             \
#        Cm-01                                              Cm-02
#         DATE ITEM_NO            ITEM_NAME STOCK SALE       DATE ITEM_NO
# 0 2023-01-07   11101     Apple 14 Pro Max     5    1 2023-01-07   11106
# 1 2023-02-07   11102         Vivo 15 Plus    10    8 2023-02-07   11107
# 2 2023-03-07   11103     Apple 13 Pro Max     4    0 2023-03-07   11108
# 3 2023-04-07   11104  Oppo Reno 10 Series     4    1 2023-04-07   11109
# 4 2023-05-07   11105          samsung S23    12    9 2023-05-07   11110
# 5 2023-06-07   15786           Realme C52    14   11 2023-06-07   11789
# 6 2023-07-07   15787       OnePlus Nord 3     8    6 2023-07-07   12346
#
#                                    ...               A                  \
#                                    ...           Cm-04           Cm-05
#              ITEM_NAME STOCK SALE  ... Sale_Percentage Sale_Percentage
# 0     Apple 14 Pro Max     5    0  ...             60%             40%
# 1        Apple 14 Plus    10    4  ...             60%             90%
# 2     Apple 13 Pro Max     4    3  ...             50%             25%
# 3  Oppo Reno 10 Series     4    2  ...             50%             75%
# 4  Oppo Reno 09 series    12    4  ...            100%             33%
# 5         Realme 11Pro     6    3  ...             13%             12%
# 6           Realme C52     8    4  ...             43%             78%
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%              0%             40%
# 1             40%             40%             40%             30%
# 2             50%             75%             25%             50%
# 3            100%             50%             50%             50%
# 4             75%             42%             33%             33%
# 5            100%              0%             91%             60%
# 6              0%             13%            100%             62%
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%             80%             60%
# 1             20%             50%             80%             90%
# 2             75%             75%             25%             25%
# 3             50%             50%             50%            100%
# 4             42%             25%             67%             92%
# 5             50%             25%             86%             50%
# 6             67%             90%             14%              0%
#
# [7 rows x 78 columns]

# %%
# Drop Date column

for column in data.columns:
    if 'DATE' in column:
        data.drop(column, axis=1, inplace=True)

# %%
data
# Out:
#    A_Plus                                                                     \
#     Cm-01                                   Cm-02
#   ITEM_NO            ITEM_NAME STOCK SALE ITEM_NO            ITEM_NAME STOCK
# 0   11101     Apple 14 Pro Max     5    1   11106     Apple 14 Pro Max     5
# 1   11102         Vivo 15 Plus    10    8   11107        Apple 14 Plus    10
# 2   11103     Apple 13 Pro Max     4    0   11108     Apple 13 Pro Max     4
# 3   11104  Oppo Reno 10 Series     4    1   11109  Oppo Reno 10 Series     4
# 4   11105          samsung S23    12    9   11110  Oppo Reno 09 series    12
# 5   15786           Realme C52    14   11   11789         Realme 11Pro     6
# 6   15787       OnePlus Nord 3     8    6   12346           Realme C52     8
#
#                                      ...               A                  \
#          Cm-03                       ...           Cm-04           Cm-05
#   SALE ITEM_NO            ITEM_NAME  ... Sale_Percentage Sale_Percentage
# 0    0   11111     Apple 14 Pro Max  ...             60%             40%
# 1    4   11112        Apple 14 Plus  ...             60%             90%
# 2    3   11113     Apple 13 Pro Max  ...             50%             25%
# 3    2   11114          samsung s21  ...             50%             75%
# 4    4   11115  Oppo Reno 09 series  ...            100%             33%
# 5    3   16934       OnePlus Nord 3  ...             13%             12%
# 6    4   16935         Realme 11Pro  ...             43%             78%
#
#                 B                                               C  \
#             Cm-06           Cm-07           Cm-08           Cm-09
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%              0%             40%
# 1             40%             40%             40%             30%
# 2             50%             75%             25%             50%
# 3            100%             50%             50%             50%
# 4             75%             42%             33%             33%
# 5            100%              0%             91%             60%
# 6              0%             13%            100%             62%
#
#
#             Cm-10           Cm-11           Cm-12           Cm-13
#   Sale_Percentage Sale_Percentage Sale_Percentage Sale_Percentage
# 0             20%             40%             80%             60%
# 1             20%             50%             80%             90%
# 2             75%             75%             25%             25%
# 3             50%             50%             50%            100%
# 4             42%             25%             67%             92%
# 5             50%             25%             86%             50%
# 6             67%             90%             14%              0%
#
# [7 rows x 65 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   (A_Plus, Cm-01, ITEM_NO)          7 non-null      int64
#  1   (A_Plus, Cm-01, ITEM_NAME)        7 non-null      object
#  2   (A_Plus, Cm-01, STOCK)            7 non-null      int64
#  3   (A_Plus, Cm-01, SALE)             7 non-null      int64
#  4   (A_Plus, Cm-02, ITEM_NO)          7 non-null      int64
#  5   (A_Plus, Cm-02, ITEM_NAME)        7 non-null      object
#  6   (A_Plus, Cm-02, STOCK)            7 non-null      int64
#  7   (A_Plus, Cm-02, SALE)             7 non-null      int64
#  8   (A_Plus, Cm-03, ITEM_NO)          7 non-null      int64
#  9   (A_Plus, Cm-03, ITEM_NAME)        7 non-null      object
#  10  (A_Plus, Cm-03, STOCK)            7 non-null      int64
#  11  (A_Plus, Cm-03, SALE)             7 non-null      int64
#  12  (A, Cm-04, ITEM_NO)               7 non-null      int64
#  13  (A, Cm-04, ITEM_NAME)             7 non-null      object
#  14  (A, Cm-04, STOCK)                 7 non-null      int64
#  15  (A, Cm-04, SALE)                  7 non-null      int64
#  16  (A, Cm-05, ITEM_NO)               7 non-null      int64
#  17  (A, Cm-05, ITEM_NAME)             7 non-null      object
#  18  (A, Cm-05, STOCK)                 7 non-null      int64
#  19  (A, Cm-05, SALE)                  7 non-null      int64
#  20  (B, Cm-06, ITEM_NO)               7 non-null      int64
#  21  (B, Cm-06, ITEM_NAME)             7 non-null      object
#  22  (B, Cm-06, STOCK)                 7 non-null      int64
#  23  (B, Cm-06, SALE)                  7 non-null      int64
#  24  (B, Cm-07, ITEM_NO)               7 non-null      int64
#  25  (B, Cm-07, ITEM_NAME)             7 non-null      object
#  26  (B, Cm-07, STOCK)                 7 non-null      int64
#  27  (B, Cm-07, SALE)                  7 non-null      int64
#  28  (B, Cm-08, ITEM_NO)               7 non-null      int64
#  29  (B, Cm-08, ITEM_NAME)             7 non-null      object
#  30  (B, Cm-08, STOCK)                 7 non-null      int64
#  31  (B, Cm-08, SALE)                  7 non-null      int64
#  32  (C, Cm-09, ITEM_NO)               7 non-null      int64
#  33  (C, Cm-09, ITEM_NAME)             7 non-null      object
#  34  (C, Cm-09, STOCK)                 7 non-null      int64
#  35  (C, Cm-09, SALE)                  7 non-null      int64
#  36  (C, Cm-10, ITEM_NO)               7 non-null      int64
#  37  (C, Cm-10, ITEM_NAME)             7 non-null      object
#  38  (C, Cm-10, STOCK)                 7 non-null      int64
#  39  (C, Cm-10, SALE)                  7 non-null      int64
#  40  (C, Cm-11, ITEM_NO)               7 non-null      int64
#  41  (C, Cm-11, ITEM_NAME)             7 non-null      object
#  42  (C, Cm-11, STOCK)                 7 non-null      int64
#  43  (C, Cm-11, SALE)                  7 non-null      int64
#  44  (C, Cm-12, ITEM_NO)               7 non-null      int64
#  45  (C, Cm-12, ITEM_NAME)             7 non-null      object
#  46  (C, Cm-12, STOCK)                 7 non-null      int64
#  47  (C, Cm-12, SALE)                  7 non-null      int64
#  48  (C, Cm-13, ITEM_NO)               7 non-null      int64
#  49  (C, Cm-13, ITEM_NAME)             7 non-null      object
#  50  (C, Cm-13, STOCK)                 7 non-null      int64
#  51  (C, Cm-13, SALE)                  7 non-null      int64
#  52  (A_Plus, Cm-01, Sale_Percentage)  7 non-null      object
#  53  (A_Plus, Cm-02, Sale_Percentage)  7 non-null      object
#  54  (A_Plus, Cm-03, Sale_Percentage)  7 non-null      object
#  55  (A, Cm-04, Sale_Percentage)       7 non-null      object
#  56  (A, Cm-05, Sale_Percentage)       7 non-null      object
#  57  (B, Cm-06, Sale_Percentage)       7 non-null      object
#  58  (B, Cm-07, Sale_Percentage)       7 non-null      object
#  59  (B, Cm-08, Sale_Percentage)       7 non-null      object
#  60  (C, Cm-09, Sale_Percentage)       7 non-null      object
#  61  (C, Cm-10, Sale_Percentage)       7 non-null      object
#  62  (C, Cm-11, Sale_Percentage)       7 non-null      object
#  63  (C, Cm-12, Sale_Percentage)       7 non-null      object
#  64  (C, Cm-13, Sale_Percentage)       7 non-null      object
# dtypes: int64(39), object(26)
# memory usage: 3.7+ KB
